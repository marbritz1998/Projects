# %% [markdown]
# # Preparing ABR Imagery 2021 Data for Analysis

# %% [markdown]
# **Will be focusing on SO Detail History View**

# %%
#import packages
import pandas as pd
import numpy as np
from datetime import datetime
from os import devnull
import xlrd

# %%
#since SO Detail History View is in .Xls format, will need to use devnull and xlrd to open
wb = xlrd.open_workbook('SO Detail History View 2021.Xls', logfile = open(devnull, 'w'))
data = pd.read_excel(wb, thousands = ',')

# %% [markdown]
# ## **Filtering to keep orders MADE in 2021**

# %%
#making transaction date and Actu Ship Date  datetime objects
data['Transaction Date'] = pd.to_datetime(data['Transaction Date'], format = "%m/%d/%Y")
data['Act Ship Date'] = pd.to_datetime(data['Act Ship Date'], format = "%m/%d/%Y")

# %%
#filtering data made in 2021
data= data[(data['Transaction Date'] >= '2021-01-01') & (data['Transaction Date'] <= '2021-12-31')]

# %%
#testing to see that it worked, great it does!
print(data['Transaction Date'].min())
print(data['Transaction Date'].max())
# Out:
# 2021-01-01 00:00:00
# 2021-12-01 00:00:00

# %% [markdown]
# # Changing type of Transaction ID to string and formating to match Traverse

# %%
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'float'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'int'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : str})

# %%
data['Transaction ID'] = data['Transaction ID'].apply(lambda x: x.zfill(8))

# %%
data.head()
#sucessful
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -100.79
# 1      NaN -620.62
# 2      NaN  -74.09
# 3      NaN -400.04
# 4      NaN -128.90

# %% [markdown]
# ## Filtering out Customer ID's that are not actually customers

# %%
customer_id_filter = ['edr0001','plt0001','Jos0118','Mag0003', 'PDK0001']
data = data[~data['Customer ID'].isin(customer_id_filter)]

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -100.79
# 1      NaN -620.62
# 2      NaN  -74.09
# 3      NaN -400.04
# 4      NaN -128.90

# %% [markdown]
# ## Saving unique items to text file to view them for any items that should't be there

# %%
np.savetxt('unique items 2021.txt', data['Item ID'].unique(), fmt='%s')

# %% [markdown]
# **All the items look good**

# %% [markdown]
# # There are many items with no Price Code, there is another alternative to use called Product Line. Will add this to the table replacing Price Code. Will check Product Line's and make sure all items have Product Lines

# %% [markdown]
# **In Traverse, got a list of all the items called 'IN Item View ALL.Xls'. This has the column called Product Line that we want. I will load this in and join with data on 'Item ID'**

# %%
#loading items
wb = xlrd.open_workbook('IN Item View ALL.Xls', logfile = open(devnull, 'w'))
items = pd.read_excel(wb)

# %%
#filtering to have only item id and prodcut lin
items = items[['Item ID', 'Product Line', 'Additional Description']]

# %%
#joining items with data
data = data.merge(items, on = 'Item ID', how = 'left')

# %%
#removing Price code
del data['Price Code']

# %%
#reordering dataframe
data = data[['History Type','Transaction ID','Customer ID','Transaction Date','Act Ship Date','Transaction Type', 'Description','Additional Description','Item ID',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units ','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#renaming units to remove whitespace
data = data.rename(columns = {'Units ': 'Units'})

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Additional Description Item ID Location ID  \
# 0          Payment         NaN                    NaN     NaN         NaN
# 1          Payment         NaN                    NaN     NaN         NaN
# 2          Payment         NaN                    NaN     NaN         NaN
# 3          Payment         NaN                    NaN     NaN         NaN
# 4          Payment         NaN                    NaN     NaN         NaN
#
#   Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 0          NaN            0.0   NaN              0.0            0.0
# 1          NaN            0.0   NaN              0.0            0.0
# 2          NaN            0.0   NaN              0.0            0.0
# 3          NaN            0.0   NaN              0.0            0.0
# 4          NaN            0.0   NaN              0.0            0.0
#
#   Price Adj Type  Unit Cost Sell Ship Via  Amount
# 0         Amount             0.0      NaN -100.79
# 1         Amount             0.0      NaN -620.62
# 2         Amount             0.0      NaN  -74.09
# 3         Amount             0.0      NaN -400.04
# 4         Amount             0.0      NaN -128.90

# %%
#removing payment History type
data = data[~(data['History Type'] == 'Payment')]

# %%
#viewing unique items that have no Product Line
data['Item ID'][(data['History Type'] == 'Line Item') & (data['Product Line'].isna())].unique()   
#why didn't this give me ALL the product lines with nan and history type line item ?
# Out:
# array(['purr-minor kit', 'purr-bravo kit', nan, 'claw11',
#        'jc-3m2fd-ac-4.5', '854-203DSK-ADPT', 'Liftgatefee', 'JC-ST14',
#        'JC-ST19', 'purr-glass pack', 'BB-46-B-BROWNHONEY', 'sun',
#        'ind-3mc-b2', 'PORTABLECCASE2', '0000-BOROBATCH-LOGO-2XL',
#        'crucible30lb', '4-2-INLET-CONVERSIONKIT',
#        'Crucible-3inchby1.5inch', 'BEGINNERKIT-NORTELREDMAX',
#        'Purr-Bravo Kit', 'GORO3D', 'GORO5', 'GOS6W', 'VW1-01680',
#        'CLAW15', 'TUNGSTEN PICK 1/8', 'JC-1014B', 'OPAL POLISHED WHITE',
#        'BB-03-M-DAVESBLUES', '854-220k', 'ind-14/10f-hw', 'ind-1fc-b2'],
#       dtype=object)

# %% [markdown]
# ### Adding Product Lines to Items with NaN Product Lines

# %% [markdown]
# **I have looked in Traverse for these Item ID's and have found their corresponding Product Line's. The only items that needed made Product Lines were crucible pots**

# %%
#replacing Prodcut lines
data.loc[(data['Item ID'] == 'LIftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'liftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'Liftgatefee'), 'Product Line'] = 'service'

purr_list = ['purr-minor kit', 'purr-bravo kit', 'purr-glass pack', 'Purr-Bravo Kit']
data.loc[(data['Item ID'].isin(purr_list)), 'Product Line'] = 'PURR'

hose_list = ['4-2-INLET-CONVERSIONKIT', '854-203DSK-ADPT', '854-220k']
data.loc[(data['Item ID'].isin(hose_list)), 'Product Line'] = 'Hoses & Acce'

bb_list = ['BB-03-M-DAVESBLUES', 'BB-46-B-BROWNHONEY']
data.loc[(data['Item ID'].isin(bb_list)), 'Product Line'] = 'Boro Batch'

data.loc[(data['Item ID'] == 'BEGINNERKIT-NORTELREDMAX'), 'Product Line'] = 'BEGINNER KIT'

claw_list = ['claw11', 'CLAW15']
data.loc[(data['Item ID'].isin(claw_list)), 'Product Line'] = 'CLAWS'

crucible_list = ['crucible30lb', 'Crucible-3inchby1.5inch']
data.loc[(data['Item ID'].isin(crucible_list)), 'Product Line'] = 'CRUCIBLE'

opal_list = ['GORO3D', 'GORO5', 'GOS6W', 'OPAL POLISHED WHITE']
data.loc[(data['Item ID'].isin(opal_list)), 'Product Line'] = 'OPALS'

joints_list = ['ind-14/10f-hw', 'ind-1fc-b2', 'ind-3mc-b2', 'JC-ST14', 'JC-ST19']
data.loc[(data['Item ID'].isin(joints_list)), 'Product Line'] = 'Glass Joints'

bushings_list = ['JC-1014B', 'jc-3m2fd-ac-4.5']
data.loc[(data['Item ID'].isin(bushings_list)), 'Product Line'] = 'Bushings'

data.loc[(data['Item ID'].isin(['PORTABLECCASE2'])), 'Product Line'] = 'CRAFT ITEMS'

data.loc[(data['Item ID'].isin(['TUNGSTEN PICK 1/8'])), 'Product Line'] = 'RAKES/PICKS'

data.loc[(data['Item ID'].isin(['VW1-01680'])), 'Product Line'] = 'HA TOOLS'

data.loc[(data['Item ID'].isin(['0000-BOROBATCH-LOGO-2XL'])), 'Product Line'] = 'T-SHIRTS'
#dropping the row with 'sun' as the item id
data = data.drop(data.loc[data['Item ID'] == 'sun'].index)

# %%
#further exploring line items with nan product line
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Freight      4483
# Sales Tax     522
# Line Item      22
# Misc            1
# Name: History Type, dtype: int64

# %%
data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 825      Line Item       00181515     tom0001       2021-11-26    2021-11-30
# 4441     Line Item       00181145     ste0474       2021-11-05           NaT
# 7030     Line Item       00180835     ian0020       2021-10-20    2021-10-20
# 11342    Line Item       00180338     dou0045       2021-09-23    2021-09-24
# 12181    Line Item       00180247     pau0049       2021-09-17    2021-09-20
# 15821    Line Item       00179869     pau0081       2021-08-26           NaT
# 18183    Line Item       00179578     Nor0008       2021-08-12           NaT
# 26794    Line Item       00178647     UOP0001       2021-06-17           NaT
# 27111    Line Item       00178609     ala0056       2021-06-16           NaT
# 28260    Line Item       00178439     mar1061       2021-06-09    2021-06-11
# 29315    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 29316    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 33881    Line Item       00177763     mar1058       2021-05-11           NaT
# 38992    Line Item       00177171     ral0008       2021-04-15           NaT
# 41715    Line Item       00176832     gle0034       2021-04-04           NaT
# 45812    Line Item       00176402     nic0101       2021-03-17           NaT
# 45822    Line Item       00176403     mat0219       2021-03-17           NaT
# 49330    Line Item       00175870     pau0081       2021-03-01           NaT
# 53502    Line Item       00175485     bre0136       2021-02-11           NaT
# 53510    Line Item       00175482     ada0034       2021-02-11    2021-03-18
# 53922    Line Item       00175447     jam0021       2021-02-09           NaT
# 57030    Line Item       00175033     TGP0001       2021-01-25           NaT
#
#       Transaction Type                                        Description  \
# 825            Invoice                                                NaN
# 4441           Invoice                                                NaN
# 7030           Invoice                                                NaN
# 11342          Invoice                                                NaN
# 12181          Invoice                                                NaN
# 15821          Invoice                                                NaN
# 18183          Invoice                                                NaN
# 26794          Invoice                                                NaN
# 27111          Invoice                                                NaN
# 28260          Invoice                                                NaN
# 29315      Credit Memo  tax credit he should not be charged tax he is ...
# 29316      Credit Memo                      refunded him tax he is exempt
# 33881          Invoice                                                NaN
# 38992          Invoice                                                NaN
# 41715          Invoice  subbed out 3 parramore rods with sage, seamist...
# 45812          Invoice                                                NaN
# 45822          Invoice                                                NaN
# 49330          Invoice                                                NaN
# 53502          Invoice                                                NaN
# 53510          Invoice                                                NaN
# 53922          Invoice                                                NaN
# 57030          Invoice                                                NaN
#
#       Additional Description Item ID Location ID Product Line  Qty Ship Sell  \
# 825                      NaN     NaN         B01          NaN            1.0
# 4441                     NaN     NaN         B01          NaN            0.0
# 7030                     NaN     NaN         B01          NaN            1.0
# 11342                    NaN     NaN         B01          NaN            1.0
# 12181                    NaN     NaN         B01          NaN            1.0
# 15821                    NaN     NaN         B01          NaN            0.0
# 18183                    NaN     NaN         B01          NaN            0.0
# 26794                    NaN     NaN         B01          NaN            0.0
# 27111                    NaN     NaN         B01          NaN            0.0
# 28260                    NaN     NaN         B01          NaN            1.0
# 29315                    NaN     NaN         B01          NaN           -1.0
# 29316                    NaN     NaN         B01          NaN            0.0
# 33881                    NaN     NaN         B01          NaN            0.0
# 38992                    NaN     NaN         B01          NaN            0.0
# 41715                    NaN     NaN         B01          NaN            0.0
# 45812                    NaN     NaN         B01          NaN            0.0
# 45822                    NaN     NaN         B01          NaN            0.0
# 49330                    NaN     NaN         B01          NaN            0.0
# 53502                    NaN     NaN         B01          NaN            0.0
# 53510                    NaN     NaN         B01          NaN            1.0
# 53922                    NaN     NaN         B01          NaN            0.0
# 57030                    NaN     NaN         B01          NaN            0.0
#
#       Units  Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 825      LB             0.00            0.0        Percent             0.0
# 4441     LB             0.00            0.0        Percent             0.0
# 7030     LB             0.00            0.0        Percent             0.0
# 11342    LB             0.00            0.0        Percent             0.0
# 12181    LB             0.00            0.0        Percent             0.0
# 15821    LB             0.00            0.0        Percent             0.0
# 18183    LB             0.00            0.0        Percent             0.0
# 26794    LB             0.00            0.0        Percent             0.0
# 27111    LB             0.00            0.0        Percent             0.0
# 28260    LB             0.00            0.0        Percent             0.0
# 29315    LB             0.00            0.0        Percent             0.0
# 29316    LB            40.15            0.0        Percent             0.0
# 33881    LB             0.00            0.0        Percent             0.0
# 38992    LB             0.00            0.0        Percent             0.0
# 41715    LB             0.00            0.0        Percent             0.0
# 45812    LB             0.00            0.0        Percent             0.0
# 45822    LB             0.00            0.0        Percent             0.0
# 49330    LB             0.00            0.0        Percent             0.0
# 53502    LB             0.00            0.0        Percent             0.0
# 53510    LB             0.00            0.0        Percent             0.0
# 53922    LB             0.00            0.0        Percent             0.0
# 57030    LB             0.00            0.0        Percent             0.0
#
#                    Ship Via  Amount
# 825                     GND     0.0
# 4441                    NaN     0.0
# 7030                    NaN     0.0
# 11342                   NaN     0.0
# 12181                   NaN     0.0
# 15821                   NaN     0.0
# 18183                   NaN     0.0
# 26794                   NaN     0.0
# 27111                   GND     0.0
# 28260                   NaN     0.0
# 29315                   NaN     0.0
# 29316                   NaN     0.0
# 33881                   GND     0.0
# 38992                   NaN     0.0
# 41715  International Econom     0.0
# 45812                   NaN     0.0
# 45822                   NaN     0.0
# 49330                   NaN     0.0
# 53502                   NaN     0.0
# 53510                   NaN     0.0
# 53922                   NaN     0.0
# 57030                   NaN     0.0

# %% [markdown]
# **Looking at the cell above, everything with practically all NaN is empty rows,  I know this by double checking the orders in Traverse, These rows can be removed.
# can remove Trans ID 00178332
# can remove index 41715, this is an emtpy line with information on items that were subbed out
# so everything from the table above can be removed from the dataset**

# %%
remove_index = data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')].index

data = data[~data.index.isin(remove_index)]

# %%
#no all the line items are dealt with
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Freight      4483
# Sales Tax     522
# Misc            1
# Name: History Type, dtype: int64

# %%
#looking at the miscallaneuous item in Traverse, this item needs to stay as it counts to what the customer paid
data.loc[(data['History Type'] == 'Misc')]

#need to keep the Freight and Sales Tax rows as well, this gives important information and these should not have a product line. in the future on this project, I may
# add product lines for these for help on getting totals for these categories, but for now, I will not put a Product Line on these
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 13202         Misc       00180135     sam0076       2021-09-10    2021-09-10
#
#       Transaction Type Description Additional Description Item ID Location ID  \
# 13202          Invoice         NaN                    NaN     NaN         B01
#
#       Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 13202          NaN            1.0   NaN            645.0            0.0
#
#       Price Adj Type  Unit Cost Sell Ship Via  Amount
# 13202         Amount             0.0      NaN   645.0

# %%
#changing dtypes of the data for values that should be numeric
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57052 entries, 34 to 62614
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            57052 non-null  object
#  1   Transaction ID          57052 non-null  object
#  2   Customer ID             57052 non-null  object
#  3   Transaction Date        57052 non-null  datetime64[ns]
#  4   Act Ship Date           55342 non-null  datetime64[ns]
#  5   Transaction Type        57052 non-null  object
#  6   Description             51938 non-null  object
#  7   Additional Description  33385 non-null  object
#  8   Item ID                 52046 non-null  object
#  9   Location ID             57052 non-null  object
#  10  Product Line            52046 non-null  object
#  11  Qty Ship Sell           57052 non-null  float64
#  12  Units                   52046 non-null  object
#  13  Unit Price Sell         57052 non-null  float64
#  14  Price Adj Pct           57052 non-null  float64
#  15  Price Adj Type          57052 non-null  object
#  16  Unit Cost Sell          57052 non-null  float64
#  17  Ship Via                45304 non-null  object
#  18  Amount                  57052 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(12)
# memory usage: 8.7+ MB

# %%
data['Qty Ship Sell'] = data['Qty Ship Sell'].astype({'Qty Ship Sell' : float})
data['Unit Price Sell'] = data['Unit Price Sell'].astype({'Unit Price Sell' : float})
data['Amount'] = data['Amount'].astype({'Amount' : float})

# %% [markdown]
# # Adding a Drop Ship column to the data.

# %% [markdown]
# **Some items are drop ship items, will add a column detailing whether a particular item is a drop ship item or not.  An item will be a drop ship item if "DROP SHIP" exists in the Additional Description**

# %%
#setting nan in additional Description to 'No Additional Description'
data['Additional Description'] = data['Additional Description'].fillna('No Additional Description')

# %%
data['Additional Description'].str.contains(pat = 'DROP SHIP')
# Out:
# 34       False
# 35       False
# 36       False
# 37       False
# 38       False
#          ...
# 62610    False
# 62611    False
# 62612    False
# 62613    False
# 62614    False
# Name: Additional Description, Length: 57052, dtype: bool

# %%
#adding column for whether an item is Drop ship 
data['Drop Ship'] = 0

# %%
#creatiing conditional for Drop ship column, will either be Y or N
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == True), 'Drop Ship'] = 'Y'
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == False), 'Drop Ship'] = 'N'

# %% [markdown]
# # Handling the rest of the NaN data in the dataset

# %%
data.isna().sum()
# Out:
# History Type                  0
# Transaction ID                0
# Customer ID                   0
# Transaction Date              0
# Act Ship Date              1710
# Transaction Type              0
# Description                5114
# Additional Description        0
# Item ID                    5006
# Location ID                   0
# Product Line               5006
# Qty Ship Sell                 0
# Units                      5006
# Unit Price Sell               0
# Price Adj Pct                 0
# Price Adj Type                0
# Unit Cost Sell                0
# Ship Via                  11748
# Amount                        0
# Drop Ship                     0
# dtype: int64

# %% [markdown]
# **for items that have NaT for actual shipping date, these are items that did not ship, will keep this NaT**

# %% [markdown]
# **Item ID, Product Line, and Units are all columns that do not have items, I will change these to 'No Item ID', 'No Product Line', 'No Units'**

# %%
data['Item ID'].fillna('No Item ID', inplace = True)
data['Product Line'].fillna('No Product Line', inplace = True)
data['Units'].fillna('No Units', inplace = True)

# %%
#for Ship via, the NaN values are unknown, so I will put 'unknown', this is because I would have to mainly go through over 10,000 entries to see what the shipping was
# in Traverse. And that is ridiculous
data.loc[(data['Ship Via'].isna())]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 34       Line Item       00181674     sas0013       2021-12-01    2021-12-01
# 35       Line Item       00181674     sas0013       2021-12-01    2021-12-01
# 36         Freight       00181674     sas0013       2021-12-01    2021-12-01
# 37       Line Item       00181672     sam0161       2021-12-01    2021-12-01
# 38       Line Item       00181672     sam0161       2021-12-01    2021-12-01
# ...            ...            ...         ...              ...           ...
# 62587    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 62588    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 62589    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 62590    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 62591      Freight       00174470     die0005       2021-01-02    2021-01-11
#
#       Transaction Type                    Description  \
# 34             Invoice                           ex-5
# 35             Invoice                           ex-5
# 36             Invoice                            NaN
# 37             Invoice    KEVLAR LATHE TAPE 2" X 1/8"
# 38             Invoice  8" Small Yellow Kevlar Gloves
# ...                ...                            ...
# 62587          Invoice               GG Blue Satin #4
# 62588          Invoice    GG Blue Cheese B Grade Tube
# 62589          Invoice    Northstar Galaxy Rod (Odds)
# 62590          Invoice           Northstar Galaxy Rod
# 62591          Invoice                            NaN
#
#                                   Additional Description            Item ID  \
# 34                             No Additional Description      sublined item
# 35                             No Additional Description      sublined item
# 36                             No Additional Description         No Item ID
# 37     Roll of Heavy Duty Lathe Tape is 2" wide and 1...      KTN44P4001200
# 38        One Pair of Reversible Yellow 8" Kevlar Glo...           855-003s
# ...                                                  ...                ...
# 62587  <h4> Item name: </h4>\n\nGreasy Glass Blue Sat...    GG-T-BlueSatin4
# 62588  <h4> Item name: </h4>\n\nGreasy Glass Blue Che...  GG-T-BlueCheese-B
# 62589  <h4> Item name: </h4>\n\nNorthstar Galaxy Rod ...             ons152
# 62590  <h4> Item name: </h4>\n\nNorthstar Galaxy Rod ...              ns152
# 62591                          No Additional Description         No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 34            B01          service            1.0        ea             0.00
# 35            B01          service            1.0        ea             0.00
# 36            B01  No Product Line            1.0  No Units            55.00
# 37            B01     Lathe Access            1.0       1/2           129.95
# 38            B01     Gloves & Sle            1.0        EA            11.95
# ...           ...              ...            ...       ...              ...
# 62587         B01     Greasy Glass            1.0        LB           120.00
# 62588         B01     Greasy Glass            1.0        LB            80.00
# 62589         B01     Northstar Ro            1.0        LB            45.00
# 62590         B01     Northstar Ro            2.0        LB            58.50
# 62591         B01  No Product Line            1.0  No Units           240.00
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via  Amount Drop Ship
# 34               0.0        Percent            0.00      NaN    0.00         N
# 35               0.0        Percent            0.00      NaN    0.00         N
# 36               0.0         Amount            0.00      NaN   55.00         N
# 37               0.0        Percent           58.12      NaN  129.95         N
# 38               0.0        Percent            0.00      NaN   11.95         N
# ...              ...            ...             ...      ...     ...       ...
# 62587            0.0         Amount           72.00      NaN  120.00         N
# 62588            0.0         Amount           35.00      NaN   80.00         N
# 62589            0.0         Amount           22.50      NaN   45.00         N
# 62590            0.0         Amount           32.50      NaN  117.00         N
# 62591            0.0         Amount            0.00      NaN  240.00         N
#
# [11748 rows x 20 columns]

# %%
#replacing ship via nan with unknown
data['Ship Via'].fillna('Unknown', inplace = True)

# %%
#Replacing Description NaN with 'No Description'
data['Description'].fillna('No Description', inplace = True)

# %%
#Great, that handles all the NaN data!
data.isna().sum()
# Out:
# History Type                 0
# Transaction ID               0
# Customer ID                  0
# Transaction Date             0
# Act Ship Date             1710
# Transaction Type             0
# Description                  0
# Additional Description       0
# Item ID                      0
# Location ID                  0
# Product Line                 0
# Qty Ship Sell                0
# Units                        0
# Unit Price Sell              0
# Price Adj Pct                0
# Price Adj Type               0
# Unit Cost Sell               0
# Ship Via                     0
# Amount                       0
# Drop Ship                    0
# dtype: int64

# %%
data
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 34       Line Item       00181674     sas0013       2021-12-01    2021-12-01
# 35       Line Item       00181674     sas0013       2021-12-01    2021-12-01
# 36         Freight       00181674     sas0013       2021-12-01    2021-12-01
# 37       Line Item       00181672     sam0161       2021-12-01    2021-12-01
# 38       Line Item       00181672     sam0161       2021-12-01    2021-12-01
# ...            ...            ...         ...              ...           ...
# 62610    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 62611    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 62612    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 62613    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 62614      Freight       00174473     ada0153       2021-01-02    2021-01-11
#
#       Transaction Type                         Description  \
# 34             Invoice                                ex-5
# 35             Invoice                                ex-5
# 36             Invoice                      No Description
# 37             Invoice         KEVLAR LATHE TAPE 2" X 1/8"
# 38             Invoice       8" Small Yellow Kevlar Gloves
# ...                ...                                 ...
# 62610          Invoice  Carlisle Bunsen #122 - Four-Barrel
# 62611          Invoice       Y-Splitter w/ Valves (Oxygen)
# 62612          Invoice    1/4" ID T-Grade Hose by the Foot
# 62613          Invoice      Y-Splitter w/ Valves (Propane)
# 62614          Invoice                      No Description
#
#                                   Additional Description        Item ID  \
# 34                             No Additional Description  sublined item
# 35                             No Additional Description  sublined item
# 36                             No Additional Description     No Item ID
# 37     Roll of Heavy Duty Lathe Tape is 2" wide and 1...  KTN44P4001200
# 38        One Pair of Reversible Yellow 8" Kevlar Glo...       855-003s
# ...                                                  ...            ...
# 62610  <h4> Item name: </h4>\n\nCarlisle Bunsen #122 ...      bunsen122
# 62611     "Y" Connection with valve - Oxygen _ "B" ma...            Y0V
# 62612  Propane and oxygen T-Grade Twin Line Hose I.D....          hosft
# 62613     Propane Y with Valves on Each Side: for use...            YPV
# 62614                          No Additional Description     No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 34            B01          service            1.0        ea             0.00
# 35            B01          service            1.0        ea             0.00
# 36            B01  No Product Line            1.0  No Units            55.00
# 37            B01     Lathe Access            1.0       1/2           129.95
# 38            B01     Gloves & Sle            1.0        EA            11.95
# ...           ...              ...            ...       ...              ...
# 62610         B01         CARLISLE            1.0        EA           139.95
# 62611         B01     Hoses & Acce            1.0        EA            39.95
# 62612         B01     Hoses & Acce            6.0        FT             2.25
# 62613         B01     Hoses & Acce            1.0        EA            39.95
# 62614         B01  No Product Line            1.0  No Units            26.45
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via  Amount Drop Ship
# 34               0.0        Percent           0.000  Unknown    0.00         N
# 35               0.0        Percent           0.000  Unknown    0.00         N
# 36               0.0         Amount           0.000  Unknown   55.00         N
# 37               0.0        Percent          58.120  Unknown  129.95         N
# 38               0.0        Percent           0.000  Unknown   11.95         N
# ...              ...            ...             ...      ...     ...       ...
# 62610            0.0         Amount         105.000      GND  139.95         N
# 62611            0.0         Amount          20.908      GND   39.95         N
# 62612            0.0         Amount           1.160      GND   13.50         N
# 62613            0.0         Amount          20.908      GND   39.95         N
# 62614            0.0         Amount           0.000      GND   26.45         N
#
# [57052 rows x 20 columns]

# %%
#restructuring data
data = data[['History Type','Transaction ID','Customer ID','Transaction Date','Act Ship Date','Transaction Type', 'Description','Additional Description','Item ID', 'Drop Ship',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#resetting index
data.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Adding geographic information to orders

# %% [markdown]
# **I have a file of all the customers and their address information called 'AR Customer View ALL.Xls'. I will join this with my data and get State and Country**

# %%
#importing Customer address
wb = xlrd.open_workbook('AR Customer View ALL.Xls', logfile = open(devnull, 'w'))
customer_data = pd.read_excel(wb)

# %%
#only need Customer ID, city, region and country
customer_data = customer_data[['Customer ID', 'City', 'Region', 'Country']]

# %%
#joining customer data with data
data = data.merge(customer_data, on = 'Customer ID', how = 'left')

# %%
data = data[['History Type','Transaction ID','Customer ID', 'City', 'Region', 'Country', 'Transaction Date','Act Ship Date','Transaction Type', 'Description',
             'Additional Description','Item ID', 'Drop Ship','Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type',
             'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID         City Region Country  \
# 0    Line Item       00181674     sas0013  Los Angeles     CA     USA
# 1    Line Item       00181674     sas0013  Los Angeles     CA     USA
# 2      Freight       00181674     sas0013  Los Angeles     CA     USA
# 3    Line Item       00181672     sam0161      Hammond     IN     USA
# 4    Line Item       00181672     sam0161      Hammond     IN     USA
#
#   Transaction Date Act Ship Date Transaction Type  \
# 0       2021-12-01    2021-12-01          Invoice
# 1       2021-12-01    2021-12-01          Invoice
# 2       2021-12-01    2021-12-01          Invoice
# 3       2021-12-01    2021-12-01          Invoice
# 4       2021-12-01    2021-12-01          Invoice
#
#                      Description  ... Location ID     Product Line  \
# 0                           ex-5  ...         B01          service
# 1                           ex-5  ...         B01          service
# 2                 No Description  ...         B01  No Product Line
# 3    KEVLAR LATHE TAPE 2" X 1/8"  ...         B01     Lathe Access
# 4  8" Small Yellow Kevlar Gloves  ...         B01     Gloves & Sle
#
#   Qty Ship Sell     Units Unit Price Sell  Price Adj Pct Price Adj Type  \
# 0           1.0        ea            0.00            0.0        Percent
# 1           1.0        ea            0.00            0.0        Percent
# 2           1.0  No Units           55.00            0.0         Amount
# 3           1.0       1/2          129.95            0.0        Percent
# 4           1.0        EA           11.95            0.0        Percent
#
#    Unit Cost Sell  Ship Via  Amount
# 0            0.00   Unknown    0.00
# 1            0.00   Unknown    0.00
# 2            0.00   Unknown   55.00
# 3           58.12   Unknown  129.95
# 4            0.00   Unknown   11.95
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Unit Cost Sell is a disaster.
#
# ## There are items with no unit cost sell, items with unit cost sell above unit price sell, and items with unit cost sell = unit price sell, this data is not useable in its current state.
#
# ## I could try to do a reasonable estimation on the unit cost sell, but it would be just that, an estimation. I may do this in the future, but for now I want to work with data that has been validated and known to be correct, not guesses

# %%
data.loc[(data['Unit Cost Sell'] >= data['Unit Price Sell'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 11492 entries, 0 to 57046
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            11492 non-null  object
#  1   Transaction ID          11492 non-null  object
#  2   Customer ID             11492 non-null  object
#  3   City                    11474 non-null  object
#  4   Region                  11254 non-null  object
#  5   Country                 11492 non-null  object
#  6   Transaction Date        11492 non-null  datetime64[ns]
#  7   Act Ship Date           11016 non-null  datetime64[ns]
#  8   Transaction Type        11492 non-null  object
#  9   Description             11492 non-null  object
#  10  Additional Description  11492 non-null  object
#  11  Item ID                 11492 non-null  object
#  12  Drop Ship               11492 non-null  object
#  13  Location ID             11492 non-null  object
#  14  Product Line            11492 non-null  object
#  15  Qty Ship Sell           11492 non-null  float64
#  16  Units                   11492 non-null  object
#  17  Unit Price Sell         11492 non-null  float64
#  18  Price Adj Pct           11492 non-null  float64
#  19  Price Adj Type          11492 non-null  object
#  20  Unit Cost Sell          11492 non-null  float64
#  21  Ship Via                11492 non-null  object
#  22  Amount                  11492 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(16)
# memory usage: 2.1+ MB

# %% [markdown]
# **removing unit cost sell from data. Can also remove Description and Additional Description as I have gotten the information that I needed from these columns**

# %%
del data['Unit Cost Sell']
del data['Description']
del data['Additional Description']

# %%
data
# Out:
#       History Type Transaction ID Customer ID              City Region  \
# 0        Line Item       00181674     sas0013       Los Angeles     CA
# 1        Line Item       00181674     sas0013       Los Angeles     CA
# 2          Freight       00181674     sas0013       Los Angeles     CA
# 3        Line Item       00181672     sam0161           Hammond     IN
# 4        Line Item       00181672     sam0161           Hammond     IN
# ...            ...            ...         ...               ...    ...
# 57047    Line Item       00174473     ada0153  Colorado Springs     CO
# 57048    Line Item       00174473     ada0153  Colorado Springs     CO
# 57049    Line Item       00174473     ada0153  Colorado Springs     CO
# 57050    Line Item       00174473     ada0153  Colorado Springs     CO
# 57051      Freight       00174473     ada0153  Colorado Springs     CO
#
#       Country Transaction Date Act Ship Date Transaction Type        Item ID  \
# 0         USA       2021-12-01    2021-12-01          Invoice  sublined item
# 1         USA       2021-12-01    2021-12-01          Invoice  sublined item
# 2         USA       2021-12-01    2021-12-01          Invoice     No Item ID
# 3         USA       2021-12-01    2021-12-01          Invoice  KTN44P4001200
# 4         USA       2021-12-01    2021-12-01          Invoice       855-003s
# ...       ...              ...           ...              ...            ...
# 57047     USA       2021-01-02    2021-01-11          Invoice      bunsen122
# 57048     USA       2021-01-02    2021-01-11          Invoice            Y0V
# 57049     USA       2021-01-02    2021-01-11          Invoice          hosft
# 57050     USA       2021-01-02    2021-01-11          Invoice            YPV
# 57051     USA       2021-01-02    2021-01-11          Invoice     No Item ID
#
#       Drop Ship Location ID     Product Line  Qty Ship Sell     Units  \
# 0             N         B01          service            1.0        ea
# 1             N         B01          service            1.0        ea
# 2             N         B01  No Product Line            1.0  No Units
# 3             N         B01     Lathe Access            1.0       1/2
# 4             N         B01     Gloves & Sle            1.0        EA
# ...         ...         ...              ...            ...       ...
# 57047         N         B01         CARLISLE            1.0        EA
# 57048         N         B01     Hoses & Acce            1.0        EA
# 57049         N         B01     Hoses & Acce            6.0        FT
# 57050         N         B01     Hoses & Acce            1.0        EA
# 57051         N         B01  No Product Line            1.0  No Units
#
#        Unit Price Sell  Price Adj Pct Price Adj Type Ship Via  Amount
# 0                 0.00            0.0        Percent  Unknown    0.00
# 1                 0.00            0.0        Percent  Unknown    0.00
# 2                55.00            0.0         Amount  Unknown   55.00
# 3               129.95            0.0        Percent  Unknown  129.95
# 4                11.95            0.0        Percent  Unknown   11.95
# ...                ...            ...            ...      ...     ...
# 57047           139.95            0.0         Amount      GND  139.95
# 57048            39.95            0.0         Amount      GND   39.95
# 57049             2.25            0.0         Amount      GND   13.50
# 57050            39.95            0.0         Amount      GND   39.95
# 57051            26.45            0.0         Amount      GND   26.45
#
# [57052 rows x 20 columns]

# %% [markdown]
# ## Looking at Address data that is NaN

# %%
data.isna().sum()
# Out:
# History Type           0
# Transaction ID         0
# Customer ID            0
# City                  99
# Region              1620
# Country                0
# Transaction Date       0
# Act Ship Date       1710
# Transaction Type       0
# Item ID                0
# Drop Ship              0
# Location ID            0
# Product Line           0
# Qty Ship Sell          0
# Units                  0
# Unit Price Sell        0
# Price Adj Pct          0
# Price Adj Type         0
# Ship Via               0
# Amount                 0
# dtype: int64

# %%
#so every country is filled. that is good, for NaN cities and Regions, I will keep NaN. I will be using Tableau for data visualization, so I believe these need to be NaN for 
#the spatial graphs to work

# %% [markdown]
# ## Great! I believe this data is ready for Visualization. will write to a file

# %%
data.to_csv('ABR Imagery 2021 Orders.csv', index = False)
