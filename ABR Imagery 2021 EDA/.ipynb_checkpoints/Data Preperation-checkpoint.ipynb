# %% [markdown]
# # Preparing ABR Imagery 2021 Data for Analysis

# %% [markdown]
# **Will be focusing on SO Detail History View**

# %%
#import packages
import pandas as pd
import numpy as np
from datetime import datetime
from os import devnull
import xlrd

# %%
#since SO Detail History View is in .Xls format, will need to use devnull and xlrd to open
wb = xlrd.open_workbook('SO Detail History View 2021.Xls', logfile = open(devnull, 'w'))
data = pd.read_excel(wb, thousands = ',')

# %% [markdown]
# ## **Filtering to keep orders MADE in 2021**

# %%
#making transaction date and Actu Ship Date  datetime objects
data['Transaction Date'] = pd.to_datetime(data['Transaction Date'], format = "%m/%d/%Y")
data['Act Ship Date'] = pd.to_datetime(data['Act Ship Date'], format = "%m/%d/%Y")

# %%
#filtering data made in 2021
data= data[(data['Transaction Date'] >= '2021-01-01') & (data['Transaction Date'] <= '2021-12-31')]

# %%
#testing to see that it worked, great it does!
print(data['Transaction Date'].min())
print(data['Transaction Date'].max())
# Out:
# 2021-01-01 00:00:00
# 2021-12-01 00:00:00

# %% [markdown]
# # Changing type of Transaction ID to string and formating to match Traverse

# %%
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'float'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'int'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : str})

# %%
data['Transaction ID'] = data['Transaction ID'].apply(lambda x: x.zfill(8))

# %%
data.head()
#sucessful
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -100.79
# 1      NaN -620.62
# 2      NaN  -74.09
# 3      NaN -400.04
# 4      NaN -128.90

# %% [markdown]
# ## Filtering out Customer ID's that are not actually customers

# %%
customer_id_filter = ['edr0001','plt0001','Jos0118','Mag0003', 'PDK0001', 'isg0001']
data = data[~data['Customer ID'].isin(customer_id_filter)]

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -100.79
# 1      NaN -620.62
# 2      NaN  -74.09
# 3      NaN -400.04
# 4      NaN -128.90

# %% [markdown]
# ## Saving unique items to text file to view them for any items that should't be there

# %%
np.savetxt('unique items 2021.txt', data['Item ID'].unique(), fmt='%s')

# %% [markdown]
# **All the items look good**

# %% [markdown]
# # There are many items with no Price Code, there is another alternative to use called Product Line. Will add this to the table replacing Price Code. Will check Product Line's and make sure all items have Product Lines

# %% [markdown]
# **In Traverse, got a list of all the items called 'IN Item View ALL.Xls'. This has the column called Product Line that we want. I will load this in and join with data on 'Item ID'**

# %%
#loading items
wb = xlrd.open_workbook('IN Item View ALL.Xls', logfile = open(devnull, 'w'))
items = pd.read_excel(wb)

# %%
#filtering to have only item id and prodcut lin
items = items[['Item ID', 'Product Line', 'Additional Description']]

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15646 entries, 0 to 15645
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Item ID                 15646 non-null  object
#  1   Product Line            15628 non-null  object
#  2   Additional Description  15467 non-null  object
# dtypes: object(3)
# memory usage: 366.8+ KB

# %%
#if there are any duplicated Items, they must be removed, this is so the join will not duplicated item ids for the orders
items.loc[(items['Item ID'].duplicated())]
# Out:
#        Item ID  Product Line  \
# 31     0041012  MORETTI TRAN
# 33     0041415  MORETTI TRAN
# 35       00456  MORETTI TRAN
# 355    1556008  MORETTI TRAN
# 357    1556012  MORETTI TRAN
# ...        ...           ...
# 15617      YTC  Asian Colore
# 15624    YTC32  Asian Colore
# 15626    YTC38  Asian Colore
# 15629    YTC44  Asian Colore
# 15631    YTC50  Asian Colore
#
#                                   Additional Description
# 31     This crystal-clear Moretti soft glass rod is 1...
# 33     This crystal-clear Moretti soft glass rod is 1...
# 35     This crystal-clear Moretti soft glass rod is 5...
# 355    Amber Pale Moretti Color Rod 104coe.   Availab...
# 357    Amber Light Moretti Color Rod 104coe.   Availa...
# ...                                                  ...
# 15617  This transparent dark amber yellow tubing is m...
# 15624  This transparent dark amber yellow tubing is m...
# 15626  This transparent dark amber yellow tubing is m...
# 15629  This transparent dark amber yellow tubing is m...
# 15631  This transparent dark amber yellow tubing is m...
#
# [1336 rows x 3 columns]

# %%
items.drop_duplicates(subset = 'Item ID', inplace = True)

# %%
#joining items with data
data = data.merge(items, on = 'Item ID', how = 'left')

# %%
data[data['Transaction ID'] == '00178603']
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 20865    Line Item       00178603     jas0097       2021-06-15    2021-06-16
# 20866    Line Item       00178603     jas0097       2021-06-15    2021-06-16
# 20867      Freight       00178603     jas0097       2021-06-15    2021-06-16
#
#       Transaction Type                          Description Item ID  \
# 20865          Invoice    Asian 25.4mm x 4.0mm Clear Tubing  AT2540
# 20866          Invoice  Asian 16mmx2.5mm-3.2mm Clear Tubing  AT1632
# 20867          Invoice                                  NaN     NaN
#
#       Location ID  Price Code  Qty Ship Sell Units   Unit Price Sell  \
# 20865         B01  ASIAN GLAS            1.0     CS            124.0
# 20866         B01  ASIAN GLAS            1.0     CS             80.0
# 20867         B01         NaN            1.0    NaN            125.0
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via  Amount  \
# 20865            0.0        Percent           6.634      NaN   124.0
# 20866            0.0        Percent          15.743      NaN    80.0
# 20867            0.0         Amount           0.000      NaN   125.0
#
#       Product Line                             Additional Description
# 20865   ASIAN TUBE  This economically priced borosilicate glass tu...
# 20866   ASIAN TUBE  This economically priced borosilicate glass tu...
# 20867          NaN                                                NaN

# %%
#removing Price code
del data['Price Code']

# %%
#reordering dataframe
data = data[['History Type','Transaction ID','Customer ID','Transaction Date','Act Ship Date','Transaction Type', 'Description','Additional Description','Item ID',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units ','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#renaming units to remove whitespace
data = data.rename(columns = {'Units ': 'Units'})

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00205712     bet0095       2021-12-01           NaT
# 1      Payment       00204681     Tod0111       2021-12-01           NaT
# 2      Payment       00205719     chr0867       2021-12-01           NaT
# 3      Payment       00205734     col0265       2021-12-01           NaT
# 4      Payment       00205720     jen0078       2021-12-01           NaT
#
#   Transaction Type Description Additional Description Item ID Location ID  \
# 0          Payment         NaN                    NaN     NaN         NaN
# 1          Payment         NaN                    NaN     NaN         NaN
# 2          Payment         NaN                    NaN     NaN         NaN
# 3          Payment         NaN                    NaN     NaN         NaN
# 4          Payment         NaN                    NaN     NaN         NaN
#
#   Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 0          NaN            0.0   NaN              0.0            0.0
# 1          NaN            0.0   NaN              0.0            0.0
# 2          NaN            0.0   NaN              0.0            0.0
# 3          NaN            0.0   NaN              0.0            0.0
# 4          NaN            0.0   NaN              0.0            0.0
#
#   Price Adj Type  Unit Cost Sell Ship Via  Amount
# 0         Amount             0.0      NaN -100.79
# 1         Amount             0.0      NaN -620.62
# 2         Amount             0.0      NaN  -74.09
# 3         Amount             0.0      NaN -400.04
# 4         Amount             0.0      NaN -128.90

# %%
#viewing unique items that have no Product Line
data['Item ID'][(data['History Type'] == 'Line Item') & (data['Product Line'].isna())].unique()   
#why didn't this give me ALL the product lines with nan and history type line item ?
# Out:
# array(['purr-minor kit', 'purr-bravo kit', nan, 'claw11',
#        'jc-3m2fd-ac-4.5', '854-203DSK-ADPT', 'Liftgatefee', 'JC-ST14',
#        'JC-ST19', 'purr-glass pack', 'BB-46-B-BROWNHONEY', 'sun',
#        'ind-3mc-b2', 'PORTABLECCASE2', '0000-BOROBATCH-LOGO-2XL',
#        'crucible30lb', '4-2-INLET-CONVERSIONKIT',
#        'Crucible-3inchby1.5inch', 'BEGINNERKIT-NORTELREDMAX',
#        'Purr-Bravo Kit', 'GORO3D', 'GORO5', 'GOS6W', 'VW1-01680',
#        'CLAW15', 'TUNGSTEN PICK 1/8', 'JC-1014B', 'OPAL POLISHED WHITE',
#        'BB-03-M-DAVESBLUES', '854-220k', 'ind-14/10f-hw', 'ind-1fc-b2'],
#       dtype=object)

# %% [markdown]
# ### Adding Product Lines to Items with NaN Product Lines

# %% [markdown]
# **I have looked in Traverse for these Item ID's and have found their corresponding Product Line's. The only items that needed made Product Lines were crucible pots**

# %%
#replacing Prodcut lines
data.loc[(data['Item ID'] == 'LIftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'liftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'Liftgatefee'), 'Product Line'] = 'service'

purr_list = ['purr-minor kit', 'purr-bravo kit', 'purr-glass pack', 'Purr-Bravo Kit']
data.loc[(data['Item ID'].isin(purr_list)), 'Product Line'] = 'PURR'

hose_list = ['4-2-INLET-CONVERSIONKIT', '854-203DSK-ADPT', '854-220k']
data.loc[(data['Item ID'].isin(hose_list)), 'Product Line'] = 'Hoses & Acce'

bb_list = ['BB-03-M-DAVESBLUES', 'BB-46-B-BROWNHONEY']
data.loc[(data['Item ID'].isin(bb_list)), 'Product Line'] = 'Boro Batch'

data.loc[(data['Item ID'] == 'BEGINNERKIT-NORTELREDMAX'), 'Product Line'] = 'BEGINNER KIT'

claw_list = ['claw11', 'CLAW15']
data.loc[(data['Item ID'].isin(claw_list)), 'Product Line'] = 'CLAWS'

crucible_list = ['crucible30lb', 'Crucible-3inchby1.5inch']
data.loc[(data['Item ID'].isin(crucible_list)), 'Product Line'] = 'CRUCIBLE'

opal_list = ['GORO3D', 'GORO5', 'GOS6W', 'OPAL POLISHED WHITE']
data.loc[(data['Item ID'].isin(opal_list)), 'Product Line'] = 'OPALS'

joints_list = ['ind-14/10f-hw', 'ind-1fc-b2', 'ind-3mc-b2', 'JC-ST14', 'JC-ST19']
data.loc[(data['Item ID'].isin(joints_list)), 'Product Line'] = 'Glass Joints'

bushings_list = ['JC-1014B', 'jc-3m2fd-ac-4.5']
data.loc[(data['Item ID'].isin(bushings_list)), 'Product Line'] = 'Bushings'

data.loc[(data['Item ID'].isin(['PORTABLECCASE2'])), 'Product Line'] = 'CRAFT ITEMS'

data.loc[(data['Item ID'].isin(['TUNGSTEN PICK 1/8'])), 'Product Line'] = 'RAKES/PICKS'

data.loc[(data['Item ID'].isin(['VW1-01680'])), 'Product Line'] = 'HA TOOLS'

data.loc[(data['Item ID'].isin(['0000-BOROBATCH-LOGO-2XL'])), 'Product Line'] = 'T-SHIRTS'
#dropping the row with 'sun' as the item id
data = data.drop(data.loc[data['Item ID'] == 'sun'].index)

# %%
#further exploring line items with nan product line
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Payment      5543
# Freight      4482
# Sales Tax     522
# Line Item      22
# Misc            1
# Name: History Type, dtype: int64

# %%
data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 649      Line Item       00181515     tom0001       2021-11-26    2021-11-30
# 3429     Line Item       00181145     ste0474       2021-11-05           NaT
# 5371     Line Item       00180835     ian0020       2021-10-20    2021-10-20
# 8644     Line Item       00180338     dou0045       2021-09-23    2021-09-24
# 9294     Line Item       00180247     pau0049       2021-09-17    2021-09-20
# 12127    Line Item       00179869     pau0081       2021-08-26           NaT
# 13927    Line Item       00179578     Nor0008       2021-08-12           NaT
# 20499    Line Item       00178647     UOP0001       2021-06-17           NaT
# 20717    Line Item       00178609     ala0056       2021-06-16           NaT
# 21574    Line Item       00178439     mar1061       2021-06-09    2021-06-11
# 22366    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 22367    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 25778    Line Item       00177763     mar1058       2021-05-11           NaT
# 29638    Line Item       00177171     ral0008       2021-04-15           NaT
# 31716    Line Item       00176832     gle0034       2021-04-04           NaT
# 34864    Line Item       00176402     nic0101       2021-03-17           NaT
# 34871    Line Item       00176403     mat0219       2021-03-17           NaT
# 37532    Line Item       00175870     pau0081       2021-03-01           NaT
# 40715    Line Item       00175485     bre0136       2021-02-11           NaT
# 40720    Line Item       00175482     ada0034       2021-02-11    2021-03-18
# 41040    Line Item       00175447     jam0021       2021-02-09           NaT
# 43419    Line Item       00175033     TGP0001       2021-01-25           NaT
#
#       Transaction Type                                        Description  \
# 649            Invoice                                                NaN
# 3429           Invoice                                                NaN
# 5371           Invoice                                                NaN
# 8644           Invoice                                                NaN
# 9294           Invoice                                                NaN
# 12127          Invoice                                                NaN
# 13927          Invoice                                                NaN
# 20499          Invoice                                                NaN
# 20717          Invoice                                                NaN
# 21574          Invoice                                                NaN
# 22366      Credit Memo  tax credit he should not be charged tax he is ...
# 22367      Credit Memo                      refunded him tax he is exempt
# 25778          Invoice                                                NaN
# 29638          Invoice                                                NaN
# 31716          Invoice  subbed out 3 parramore rods with sage, seamist...
# 34864          Invoice                                                NaN
# 34871          Invoice                                                NaN
# 37532          Invoice                                                NaN
# 40715          Invoice                                                NaN
# 40720          Invoice                                                NaN
# 41040          Invoice                                                NaN
# 43419          Invoice                                                NaN
#
#       Additional Description Item ID Location ID Product Line  Qty Ship Sell  \
# 649                      NaN     NaN         B01          NaN            1.0
# 3429                     NaN     NaN         B01          NaN            0.0
# 5371                     NaN     NaN         B01          NaN            1.0
# 8644                     NaN     NaN         B01          NaN            1.0
# 9294                     NaN     NaN         B01          NaN            1.0
# 12127                    NaN     NaN         B01          NaN            0.0
# 13927                    NaN     NaN         B01          NaN            0.0
# 20499                    NaN     NaN         B01          NaN            0.0
# 20717                    NaN     NaN         B01          NaN            0.0
# 21574                    NaN     NaN         B01          NaN            1.0
# 22366                    NaN     NaN         B01          NaN           -1.0
# 22367                    NaN     NaN         B01          NaN            0.0
# 25778                    NaN     NaN         B01          NaN            0.0
# 29638                    NaN     NaN         B01          NaN            0.0
# 31716                    NaN     NaN         B01          NaN            0.0
# 34864                    NaN     NaN         B01          NaN            0.0
# 34871                    NaN     NaN         B01          NaN            0.0
# 37532                    NaN     NaN         B01          NaN            0.0
# 40715                    NaN     NaN         B01          NaN            0.0
# 40720                    NaN     NaN         B01          NaN            1.0
# 41040                    NaN     NaN         B01          NaN            0.0
# 43419                    NaN     NaN         B01          NaN            0.0
#
#       Units  Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 649      LB             0.00            0.0        Percent             0.0
# 3429     LB             0.00            0.0        Percent             0.0
# 5371     LB             0.00            0.0        Percent             0.0
# 8644     LB             0.00            0.0        Percent             0.0
# 9294     LB             0.00            0.0        Percent             0.0
# 12127    LB             0.00            0.0        Percent             0.0
# 13927    LB             0.00            0.0        Percent             0.0
# 20499    LB             0.00            0.0        Percent             0.0
# 20717    LB             0.00            0.0        Percent             0.0
# 21574    LB             0.00            0.0        Percent             0.0
# 22366    LB             0.00            0.0        Percent             0.0
# 22367    LB            40.15            0.0        Percent             0.0
# 25778    LB             0.00            0.0        Percent             0.0
# 29638    LB             0.00            0.0        Percent             0.0
# 31716    LB             0.00            0.0        Percent             0.0
# 34864    LB             0.00            0.0        Percent             0.0
# 34871    LB             0.00            0.0        Percent             0.0
# 37532    LB             0.00            0.0        Percent             0.0
# 40715    LB             0.00            0.0        Percent             0.0
# 40720    LB             0.00            0.0        Percent             0.0
# 41040    LB             0.00            0.0        Percent             0.0
# 43419    LB             0.00            0.0        Percent             0.0
#
#                    Ship Via  Amount
# 649                     GND     0.0
# 3429                    NaN     0.0
# 5371                    NaN     0.0
# 8644                    NaN     0.0
# 9294                    NaN     0.0
# 12127                   NaN     0.0
# 13927                   NaN     0.0
# 20499                   NaN     0.0
# 20717                   GND     0.0
# 21574                   NaN     0.0
# 22366                   NaN     0.0
# 22367                   NaN     0.0
# 25778                   GND     0.0
# 29638                   NaN     0.0
# 31716  International Econom     0.0
# 34864                   NaN     0.0
# 34871                   NaN     0.0
# 37532                   NaN     0.0
# 40715                   NaN     0.0
# 40720                   NaN     0.0
# 41040                   NaN     0.0
# 43419                   NaN     0.0

# %% [markdown]
# **Looking at the cell above, everything with practically all NaN is empty rows,  I know this by double checking the orders in Traverse, These rows can be removed.
# can remove Trans ID 00178332
# can remove index 41715, this is an emtpy line with information on items that were subbed out
# so everything from the table above can be removed from the dataset**

# %%
remove_index = data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')].index

data = data[~data.index.isin(remove_index)]

# %%
#no all the line items are dealt with
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Payment      5543
# Freight      4482
# Sales Tax     522
# Misc            1
# Name: History Type, dtype: int64

# %%
#looking at the miscallaneuous item in Traverse, this item needs to stay as it counts to what the customer paid
data.loc[(data['History Type'] == 'Misc')]

#need to keep the Freight and Sales Tax rows as well, this gives important information and these should not have a product line. in the future on this project, I may
# add product lines for these for help on getting totals for these categories, but for now, I will not put a Product Line on these
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 10088         Misc       00180135     sam0076       2021-09-10    2021-09-10
#
#       Transaction Type Description Additional Description Item ID Location ID  \
# 10088          Invoice         NaN                    NaN     NaN         B01
#
#       Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 10088          NaN            1.0   NaN            645.0            0.0
#
#       Price Adj Type  Unit Cost Sell Ship Via  Amount
# 10088         Amount             0.0      NaN   645.0

# %%
#changing dtypes of the data for values that should be numeric
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 47682 entries, 0 to 47704
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            47682 non-null  object
#  1   Transaction ID          47682 non-null  object
#  2   Customer ID             47682 non-null  object
#  3   Transaction Date        47682 non-null  datetime64[ns]
#  4   Act Ship Date           40834 non-null  datetime64[ns]
#  5   Transaction Type        47682 non-null  object
#  6   Description             37079 non-null  object
#  7   Additional Description  27281 non-null  object
#  8   Item ID                 37134 non-null  object
#  9   Location ID             42139 non-null  object
#  10  Product Line            37134 non-null  object
#  11  Qty Ship Sell           47682 non-null  float64
#  12  Units                   37134 non-null  object
#  13  Unit Price Sell         47682 non-null  float64
#  14  Price Adj Pct           47682 non-null  float64
#  15  Price Adj Type          47682 non-null  object
#  16  Unit Cost Sell          47682 non-null  float64
#  17  Ship Via                33211 non-null  object
#  18  Amount                  47682 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(12)
# memory usage: 7.3+ MB

# %%
data['Qty Ship Sell'] = data['Qty Ship Sell'].astype({'Qty Ship Sell' : float})
data['Unit Price Sell'] = data['Unit Price Sell'].astype({'Unit Price Sell' : float})
data['Amount'] = data['Amount'].astype({'Amount' : float})

# %% [markdown]
# # Adding a Drop Ship column to the data.

# %% [markdown]
# **Some items are drop ship items, will add a column detailing whether a particular item is a drop ship item or not.  An item will be a drop ship item if "DROP SHIP" exists in the Additional Description**

# %%
#setting nan in additional Description to 'No Additional Description'
data['Additional Description'] = data['Additional Description'].fillna('No Additional Description')

# %%
data['Additional Description'].str.contains(pat = 'DROP SHIP')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 47700    False
# 47701    False
# 47702    False
# 47703    False
# 47704    False
# Name: Additional Description, Length: 47682, dtype: bool

# %%
#adding column for whether an item is Drop ship 
data['Drop Ship'] = 0

# %%
#creatiing conditional for Drop ship column, will either be Y or N
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == True), 'Drop Ship'] = 'Y'
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == False), 'Drop Ship'] = 'N'

# %% [markdown]
# # Handling the rest of the NaN data in the dataset

# %%
data.isna().sum()
# Out:
# History Type                  0
# Transaction ID                0
# Customer ID                   0
# Transaction Date              0
# Act Ship Date              6848
# Transaction Type              0
# Description               10603
# Additional Description        0
# Item ID                   10548
# Location ID                5543
# Product Line              10548
# Qty Ship Sell                 0
# Units                     10548
# Unit Price Sell               0
# Price Adj Pct                 0
# Price Adj Type                0
# Unit Cost Sell                0
# Ship Via                  14471
# Amount                        0
# Drop Ship                     0
# dtype: int64

# %% [markdown]
# **for items that have NaT for actual shipping date, these are items that did not ship, will keep this NaT**

# %% [markdown]
# **Item ID, Product Line, and Units are all columns that do not have items, I will change these to 'No Item ID', 'No Product Line', 'No Units'**

# %%
data['Item ID'].fillna('No Item ID', inplace = True)
data['Product Line'].fillna('No Product Line', inplace = True)
data['Units'].fillna('No Units', inplace = True)

# %%
#for Ship via, the NaN values are unknown, so I will put 'unknown', this is because I would have to mainly go through over 10,000 entries to see what the shipping was
# in Traverse. And that is ridiculous
data.loc[(data['Ship Via'].isna())]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0          Payment       00205712     bet0095       2021-12-01           NaT
# 1          Payment       00204681     Tod0111       2021-12-01           NaT
# 2          Payment       00205719     chr0867       2021-12-01           NaT
# 3          Payment       00205734     col0265       2021-12-01           NaT
# 4          Payment       00205720     jen0078       2021-12-01           NaT
# ...            ...            ...         ...              ...           ...
# 47682    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 47683      Freight       00174470     die0005       2021-01-02    2021-01-11
# 47702      Payment       00191070     ran0051       2021-01-02           NaT
# 47703      Payment       00191077     nic0216       2021-01-01           NaT
# 47704      Payment       00191102     cha0637       2021-01-01           NaT
#
#       Transaction Type           Description  \
# 0              Payment                   NaN
# 1              Payment                   NaN
# 2              Payment                   NaN
# 3              Payment                   NaN
# 4              Payment                   NaN
# ...                ...                   ...
# 47682          Invoice  Northstar Galaxy Rod
# 47683          Invoice                   NaN
# 47702          Payment                   NaN
# 47703          Payment                   NaN
# 47704          Payment                   NaN
#
#                                   Additional Description     Item ID  \
# 0                              No Additional Description  No Item ID
# 1                              No Additional Description  No Item ID
# 2                              No Additional Description  No Item ID
# 3                              No Additional Description  No Item ID
# 4                              No Additional Description  No Item ID
# ...                                                  ...         ...
# 47682  <h4> Item name: </h4>\n\nNorthstar Galaxy Rod ...       ns152
# 47683                          No Additional Description  No Item ID
# 47702                          No Additional Description  No Item ID
# 47703                          No Additional Description  No Item ID
# 47704                          No Additional Description  No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 0             NaN  No Product Line            0.0  No Units              0.0
# 1             NaN  No Product Line            0.0  No Units              0.0
# 2             NaN  No Product Line            0.0  No Units              0.0
# 3             NaN  No Product Line            0.0  No Units              0.0
# 4             NaN  No Product Line            0.0  No Units              0.0
# ...           ...              ...            ...       ...              ...
# 47682         B01     Northstar Ro            2.0        LB             58.5
# 47683         B01  No Product Line            1.0  No Units            240.0
# 47702         NaN  No Product Line            0.0  No Units              0.0
# 47703         NaN  No Product Line            0.0  No Units              0.0
# 47704         NaN  No Product Line            0.0  No Units              0.0
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via   Amount  \
# 0                0.0         Amount             0.0      NaN  -100.79
# 1                0.0         Amount             0.0      NaN  -620.62
# 2                0.0         Amount             0.0      NaN   -74.09
# 3                0.0         Amount             0.0      NaN  -400.04
# 4                0.0         Amount             0.0      NaN  -128.90
# ...              ...            ...             ...      ...      ...
# 47682            0.0         Amount            32.5      NaN   117.00
# 47683            0.0         Amount             0.0      NaN   240.00
# 47702            0.0         Amount             0.0      NaN -1592.50
# 47703            0.0         Amount             0.0      NaN -1076.35
# 47704            0.0         Amount             0.0      NaN   -52.72
#
#       Drop Ship
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 47682         N
# 47683         N
# 47702         N
# 47703         N
# 47704         N
#
# [14471 rows x 20 columns]

# %%
#replacing ship via nan with unknown
data['Ship Via'].fillna('Unknown', inplace = True)

# %%
#Replacing Description NaN with 'No Description'
data['Description'].fillna('No Description', inplace = True)

# %%
#Great, that handles all the NaN data!
data.isna().sum()
# Out:
# History Type                 0
# Transaction ID               0
# Customer ID                  0
# Transaction Date             0
# Act Ship Date             6848
# Transaction Type             0
# Description                  0
# Additional Description       0
# Item ID                      0
# Location ID               5543
# Product Line                 0
# Qty Ship Sell                0
# Units                        0
# Unit Price Sell              0
# Price Adj Pct                0
# Price Adj Type               0
# Unit Cost Sell               0
# Ship Via                     0
# Amount                       0
# Drop Ship                    0
# dtype: int64

# %%
data
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0          Payment       00205712     bet0095       2021-12-01           NaT
# 1          Payment       00204681     Tod0111       2021-12-01           NaT
# 2          Payment       00205719     chr0867       2021-12-01           NaT
# 3          Payment       00205734     col0265       2021-12-01           NaT
# 4          Payment       00205720     jen0078       2021-12-01           NaT
# ...            ...            ...         ...              ...           ...
# 47700    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 47701      Freight       00174473     ada0153       2021-01-02    2021-01-11
# 47702      Payment       00191070     ran0051       2021-01-02           NaT
# 47703      Payment       00191077     nic0216       2021-01-01           NaT
# 47704      Payment       00191102     cha0637       2021-01-01           NaT
#
#       Transaction Type                     Description  \
# 0              Payment                  No Description
# 1              Payment                  No Description
# 2              Payment                  No Description
# 3              Payment                  No Description
# 4              Payment                  No Description
# ...                ...                             ...
# 47700          Invoice  Y-Splitter w/ Valves (Propane)
# 47701          Invoice                  No Description
# 47702          Payment                  No Description
# 47703          Payment                  No Description
# 47704          Payment                  No Description
#
#                                   Additional Description     Item ID  \
# 0                              No Additional Description  No Item ID
# 1                              No Additional Description  No Item ID
# 2                              No Additional Description  No Item ID
# 3                              No Additional Description  No Item ID
# 4                              No Additional Description  No Item ID
# ...                                                  ...         ...
# 47700     Propane Y with Valves on Each Side: for use...         YPV
# 47701                          No Additional Description  No Item ID
# 47702                          No Additional Description  No Item ID
# 47703                          No Additional Description  No Item ID
# 47704                          No Additional Description  No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 0             NaN  No Product Line            0.0  No Units             0.00
# 1             NaN  No Product Line            0.0  No Units             0.00
# 2             NaN  No Product Line            0.0  No Units             0.00
# 3             NaN  No Product Line            0.0  No Units             0.00
# 4             NaN  No Product Line            0.0  No Units             0.00
# ...           ...              ...            ...       ...              ...
# 47700         B01     Hoses & Acce            1.0        EA            39.95
# 47701         B01  No Product Line            1.0  No Units            26.45
# 47702         NaN  No Product Line            0.0  No Units             0.00
# 47703         NaN  No Product Line            0.0  No Units             0.00
# 47704         NaN  No Product Line            0.0  No Units             0.00
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via   Amount  \
# 0                0.0         Amount           0.000  Unknown  -100.79
# 1                0.0         Amount           0.000  Unknown  -620.62
# 2                0.0         Amount           0.000  Unknown   -74.09
# 3                0.0         Amount           0.000  Unknown  -400.04
# 4                0.0         Amount           0.000  Unknown  -128.90
# ...              ...            ...             ...      ...      ...
# 47700            0.0         Amount          20.908      GND    39.95
# 47701            0.0         Amount           0.000      GND    26.45
# 47702            0.0         Amount           0.000  Unknown -1592.50
# 47703            0.0         Amount           0.000  Unknown -1076.35
# 47704            0.0         Amount           0.000  Unknown   -52.72
#
#       Drop Ship
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 47700         N
# 47701         N
# 47702         N
# 47703         N
# 47704         N
#
# [47682 rows x 20 columns]

# %%
#restructuring data
data = data[['History Type','Transaction ID','Transaction Type','Customer ID','Transaction Date','Act Ship Date', 'Description','Additional Description','Item ID', 'Drop Ship',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#resetting index
data.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Adding geographic information to orders

# %% [markdown]
# **I have made a file from Traverse with the Shipping Information for the Orders in this dataset, the file is 'AR Transaction View ALL.Xls'. I will load this data in and join to the main dataset on Transaction ID**

# %%
#importing Customer address
wb = xlrd.open_workbook('AR Transaction History View ALL.Xls', logfile = open(devnull, 'w'))
customer_data = pd.read_excel(wb)

# %%
customer_data.head()
# Out:
#   Customer ID  Transaction ID Transaction Type  Invoice Number Ship To City  \
# 0     djm0002          181679          Invoice          120588  Bloomington
# 1     sas0013          181674          Invoice          120568  Los Angeles
# 2     rya0020          181673          Invoice          120566  Bloomington
# 3     sam0161          181672          Invoice          120570      Hammond
# 4     pur0003          181671          Invoice          120575        Hemet
#
#   Ship To Region Ship To Country Invoice Date   Total
# 0            NaN             USA    12/1/2021   38.24
# 1             CA             USA    12/1/2021   55.00
# 2             IN             USA    12/1/2021  378.45
# 3             IN             USA    12/1/2021  169.06
# 4             CA             USA    12/1/2021  600.00

# %%
#changing Transaction ID to fit Traverse format
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : 'float'})
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : 'int'})
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : str})
customer_data['Transaction ID'] = customer_data['Transaction ID'].apply(lambda x: x.zfill(8))

# %%
#only need Customer ID, city, region and country
customer_data = customer_data[['Transaction ID', 'Ship To City', 'Ship To Region', 'Ship To Country']]

# %%
data.columns
# Out:
# Index(['History Type', 'Transaction ID', 'Transaction Type', 'Customer ID',
#        'Transaction Date', 'Act Ship Date', 'Description',
#        'Additional Description', 'Item ID', 'Drop Ship', 'Location ID',
#        'Product Line', 'Qty Ship Sell', 'Units', 'Unit Price Sell',
#        'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via',
#        'Amount'],
#       dtype='object')

# %%
#joining customer data with data
data = data.merge(customer_data, on = 'Transaction ID', how = 'left')

# %%
data = data[['History Type','Transaction ID', 'Transaction Type', 'Customer ID', 'Ship To City', 'Ship To Region', 'Ship To Country', 'Transaction Date','Act Ship Date',
             'Description', 'Additional Description','Item ID', 'Drop Ship','Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 
             'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
data.head()
# Out:
#   History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 0      Payment       00205712          Payment     bet0095          NaN
# 1      Payment       00204681          Payment     Tod0111          NaN
# 2      Payment       00205719          Payment     chr0867          NaN
# 3      Payment       00205734          Payment     col0265          NaN
# 4      Payment       00205720          Payment     jen0078          NaN
#
#   Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 0            NaN             NaN       2021-12-01           NaT
# 1            NaN             NaN       2021-12-01           NaT
# 2            NaN             NaN       2021-12-01           NaT
# 3            NaN             NaN       2021-12-01           NaT
# 4            NaN             NaN       2021-12-01           NaT
#
#       Description  ... Location ID     Product Line Qty Ship Sell     Units  \
# 0  No Description  ...         NaN  No Product Line           0.0  No Units
# 1  No Description  ...         NaN  No Product Line           0.0  No Units
# 2  No Description  ...         NaN  No Product Line           0.0  No Units
# 3  No Description  ...         NaN  No Product Line           0.0  No Units
# 4  No Description  ...         NaN  No Product Line           0.0  No Units
#
#   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  Ship Via  \
# 0             0.0            0.0         Amount             0.0   Unknown
# 1             0.0            0.0         Amount             0.0   Unknown
# 2             0.0            0.0         Amount             0.0   Unknown
# 3             0.0            0.0         Amount             0.0   Unknown
# 4             0.0            0.0         Amount             0.0   Unknown
#
#    Amount
# 0 -100.79
# 1 -620.62
# 2  -74.09
# 3 -400.04
# 4 -128.90
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Unit Cost Sell is a disaster.
#
# ## There are items with no unit cost sell, items with unit cost sell above unit price sell, and items with unit cost sell = unit price sell, this data is not useable in its current state.
#
# ## I could try to do a reasonable estimation on the unit cost sell, but it would be just that, an estimation. I may do this in the future, but for now I want to work with data that has been validated and known to be correct, not guesses

# %%
data.loc[(data['Unit Cost Sell'] >= data['Unit Price Sell'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12270 entries, 0 to 48871
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            12270 non-null  object
#  1   Transaction ID          12270 non-null  object
#  2   Transaction Type        12270 non-null  object
#  3   Customer ID             12270 non-null  object
#  4   Ship To City            6729 non-null   object
#  5   Ship To Region          6631 non-null   object
#  6   Ship To Country         6742 non-null   object
#  7   Transaction Date        12270 non-null  datetime64[ns]
#  8   Act Ship Date           6333 non-null   datetime64[ns]
#  9   Description             12270 non-null  object
#  10  Additional Description  12270 non-null  object
#  11  Item ID                 12270 non-null  object
#  12  Drop Ship               12270 non-null  object
#  13  Location ID             6727 non-null   object
#  14  Product Line            12270 non-null  object
#  15  Qty Ship Sell           12270 non-null  float64
#  16  Units                   12270 non-null  object
#  17  Unit Price Sell         12270 non-null  float64
#  18  Price Adj Pct           12270 non-null  float64
#  19  Price Adj Type          12270 non-null  object
#  20  Unit Cost Sell          12270 non-null  float64
#  21  Ship Via                12270 non-null  object
#  22  Amount                  12270 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(16)
# memory usage: 2.2+ MB

# %% [markdown]
# **removing unit cost sell from data. Can also remove Description and Additional Description as I have gotten the information that I needed from these columns**

# %%
del data['Unit Cost Sell']
del data['Description']
del data['Additional Description']

# %%
data
# Out:
#       History Type Transaction ID Transaction Type Customer ID  \
# 0          Payment       00205712          Payment     bet0095
# 1          Payment       00204681          Payment     Tod0111
# 2          Payment       00205719          Payment     chr0867
# 3          Payment       00205734          Payment     col0265
# 4          Payment       00205720          Payment     jen0078
# ...            ...            ...              ...         ...
# 48867    Line Item       00174473          Invoice     ada0153
# 48868      Freight       00174473          Invoice     ada0153
# 48869      Payment       00191070          Payment     ran0051
# 48870      Payment       00191077          Payment     nic0216
# 48871      Payment       00191102          Payment     cha0637
#
#            Ship To City Ship To Region Ship To Country Transaction Date  \
# 0                   NaN            NaN             NaN       2021-12-01
# 1                   NaN            NaN             NaN       2021-12-01
# 2                   NaN            NaN             NaN       2021-12-01
# 3                   NaN            NaN             NaN       2021-12-01
# 4                   NaN            NaN             NaN       2021-12-01
# ...                 ...            ...             ...              ...
# 48867  Colorado Springs             CO             USA       2021-01-02
# 48868  Colorado Springs             CO             USA       2021-01-02
# 48869               NaN            NaN             NaN       2021-01-02
# 48870               NaN            NaN             NaN       2021-01-01
# 48871               NaN            NaN             NaN       2021-01-01
#
#       Act Ship Date     Item ID Drop Ship Location ID     Product Line  \
# 0               NaT  No Item ID         N         NaN  No Product Line
# 1               NaT  No Item ID         N         NaN  No Product Line
# 2               NaT  No Item ID         N         NaN  No Product Line
# 3               NaT  No Item ID         N         NaN  No Product Line
# 4               NaT  No Item ID         N         NaN  No Product Line
# ...             ...         ...       ...         ...              ...
# 48867    2021-01-11         YPV         N         B01     Hoses & Acce
# 48868    2021-01-11  No Item ID         N         B01  No Product Line
# 48869           NaT  No Item ID         N         NaN  No Product Line
# 48870           NaT  No Item ID         N         NaN  No Product Line
# 48871           NaT  No Item ID         N         NaN  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 0                0.0  No Units             0.00            0.0         Amount
# 1                0.0  No Units             0.00            0.0         Amount
# 2                0.0  No Units             0.00            0.0         Amount
# 3                0.0  No Units             0.00            0.0         Amount
# 4                0.0  No Units             0.00            0.0         Amount
# ...              ...       ...              ...            ...            ...
# 48867            1.0        EA            39.95            0.0         Amount
# 48868            1.0  No Units            26.45            0.0         Amount
# 48869            0.0  No Units             0.00            0.0         Amount
# 48870            0.0  No Units             0.00            0.0         Amount
# 48871            0.0  No Units             0.00            0.0         Amount
#
#       Ship Via   Amount
# 0      Unknown  -100.79
# 1      Unknown  -620.62
# 2      Unknown   -74.09
# 3      Unknown  -400.04
# 4      Unknown  -128.90
# ...        ...      ...
# 48867      GND    39.95
# 48868      GND    26.45
# 48869  Unknown -1592.50
# 48870  Unknown -1076.35
# 48871  Unknown   -52.72
#
# [48872 rows x 20 columns]

# %% [markdown]
# ## Looking at Address data that is NaN

# %%
data.isna().sum()
# Out:
# History Type           0
# Transaction ID         0
# Transaction Type       0
# Customer ID            0
# Ship To City        5608
# Ship To Region      6646
# Ship To Country     5528
# Transaction Date       0
# Act Ship Date       7345
# Item ID                0
# Drop Ship              0
# Location ID         5543
# Product Line           0
# Qty Ship Sell          0
# Units                  0
# Unit Price Sell        0
# Price Adj Pct          0
# Price Adj Type         0
# Ship Via               0
# Amount                 0
# dtype: int64

# %% [markdown]
# **So I only need Region information for orders made in the USA (since my visualizations for international orders will be at country level, not region level). So I will need to fill in the Regions in the USA that are empty**

# %%
data.loc[((data['Ship To Region'].isna()) & (data['Ship To Country'].isin(['USA', 'UNITED']))), ['Ship To City']].value_counts()
# Out:
# Ship To City
# Bloomington     73
# Evansville       6
# esperance        1
# dtype: int64

# %%
#Bloomington and Evansville are in the State of Indiana. going to explore esperance

# %%
data.loc[(data['Ship To City'] == 'esperance')]

#we are only interested with the City Esperance in the USA. Looking in Traverseon the Transaction ID 00179220, the state is WA
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 16710    Line Item       00179220      Credit Memo     bea0047    esperance
# 17298    Line Item       00179135          Invoice     bea0047    esperance
# 17299    Line Item       00179135          Invoice     bea0047    esperance
# 17300    Line Item       00179135          Invoice     bea0047    esperance
# 17301    Line Item       00179135          Invoice     bea0047    esperance
# 17302    Line Item       00179135          Invoice     bea0047    esperance
# 17303    Line Item       00179135          Invoice     bea0047    esperance
# 17304    Line Item       00179135          Invoice     bea0047    esperance
# 17305    Line Item       00179135          Invoice     bea0047    esperance
# 17306    Line Item       00179135          Invoice     bea0047    esperance
# 17307    Line Item       00179135          Invoice     bea0047    esperance
# 17308    Line Item       00179135          Invoice     bea0047    esperance
# 17309      Freight       00179135          Invoice     bea0047    esperance
# 26233    Line Item       00177781          Invoice     bea0047    esperance
# 26234    Line Item       00177781          Invoice     bea0047    esperance
# 26235    Line Item       00177781          Invoice     bea0047    esperance
# 26236    Line Item       00177781          Invoice     bea0047    esperance
# 26237    Line Item       00177781          Invoice     bea0047    esperance
# 26238    Line Item       00177781          Invoice     bea0047    esperance
# 26239    Line Item       00177781          Invoice     bea0047    esperance
# 26240    Line Item       00177781          Invoice     bea0047    esperance
# 26241    Line Item       00177781          Invoice     bea0047    esperance
# 26242    Line Item       00177781          Invoice     bea0047    esperance
# 26243    Line Item       00177781          Invoice     bea0047    esperance
# 26244    Line Item       00177781          Invoice     bea0047    esperance
# 26245    Line Item       00177781          Invoice     bea0047    esperance
# 26246      Freight       00177781          Invoice     bea0047    esperance
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 16710            NaN             USA       2021-07-21    2021-07-21
# 17298             WA             AUS       2021-07-16    2021-07-20
# 17299             WA             AUS       2021-07-16    2021-07-20
# 17300             WA             AUS       2021-07-16    2021-07-20
# 17301             WA             AUS       2021-07-16    2021-07-20
# 17302             WA             AUS       2021-07-16    2021-07-20
# 17303             WA             AUS       2021-07-16    2021-07-20
# 17304             WA             AUS       2021-07-16    2021-07-20
# 17305             WA             AUS       2021-07-16    2021-07-20
# 17306             WA             AUS       2021-07-16           NaT
# 17307             WA             AUS       2021-07-16    2021-07-20
# 17308             WA             AUS       2021-07-16    2021-07-20
# 17309             WA             AUS       2021-07-16    2021-07-20
# 26233             WA             AUS       2021-05-11    2021-05-13
# 26234             WA             AUS       2021-05-11    2021-05-13
# 26235             WA             AUS       2021-05-11    2021-05-13
# 26236             WA             AUS       2021-05-11    2021-05-13
# 26237             WA             AUS       2021-05-11    2021-05-13
# 26238             WA             AUS       2021-05-11    2021-05-13
# 26239             WA             AUS       2021-05-11    2021-05-13
# 26240             WA             AUS       2021-05-11    2021-05-13
# 26241             WA             AUS       2021-05-11    2021-05-13
# 26242             WA             AUS       2021-05-11    2021-05-13
# 26243             WA             AUS       2021-05-11    2021-05-13
# 26244             WA             AUS       2021-05-11    2021-05-13
# 26245             WA             AUS       2021-05-11    2021-05-13
# 26246             WA             AUS       2021-05-11    2021-05-13
#
#                        Item ID Drop Ship Location ID     Product Line  \
# 16710            sublined item         N         B01          service
# 17298            ABR INSURANCE         N         B01        INSURANCE
# 17299  Handling and-or cod fee         N         B01          service
# 17300                  854-214         N         B01          Swivels
# 17301        GTT-BT-Phantom-4S         N         B01              GTT
# 17302             bunsenh-5600         N         B01     Bunsen Burne
# 17303            ggt-Rock-ItFP         N         B01      FOOT PEDALS
# 17304                  cshear8         N         B01     CUTTING TOOL
# 17305                   ggt-ct         N         B01            CLAWS
# 17306          BS-BS-M-Phantom         Y         B01     Torch Marver
# 17307                  854-610         N         B01     Hoses & Acce
# 17308                 Infini-V         N         B01     BENCHROLLERS
# 17309               No Item ID         N         B01  No Product Line
# 26233            ABR INSURANCE         N         B01        INSURANCE
# 26234  Handling and-or cod fee         N         B01          service
# 26235                  850-518         N         B01          REAMERS
# 26236                  854-336         N         B01       HAND TOOLS
# 26237            ggt-cricket-L         N         B01         GRAPHITE
# 26238                 SE-DD315         N         B01     TEXTURE TOOL
# 26239              547TWEEZERS         N         B01       HAND TOOLS
# 26240                    525SF         N         B01       HAND TOOLS
# 26241                 SH-AG-A2         N         B01     CUTTING TOOL
# 26242                  854-419         N         B01         TWEEZERS
# 26243            GTT-BT-Bobcat         N         B01              GTT
# 26244             bunsenh-5805         N         B01     Bunsen Burne
# 26245                    14205         N         B01     little torch
# 26246               No Item ID         N         B01  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 16710           -1.0        ea           145.00            0.0        Percent
# 17298            1.0        EA            25.30            0.0         Amount
# 17299            1.0        EA            49.25            0.0         Amount
# 17300            1.0      Each            50.00            0.0         Amount
# 17301            1.0      EACH          1200.00            0.0         Amount
# 17302            1.0      Each            68.00            0.0         Amount
# 17303            1.0        EA           440.00            0.0         Amount
# 17304            1.0      EACH            45.00            0.0         Amount
# 17305            1.0        EA            65.00            0.0         Amount
# 17306            0.0        EA           145.00            0.0         Amount
# 17307            1.0        EA             3.00            0.0         Amount
# 17308            1.0      Each           100.00            0.0         Amount
# 17309            1.0  No Units           430.00            0.0         Amount
# 26233            1.0        EA             6.90            0.0         Amount
# 26234            1.0        EA             7.29            0.0         Amount
# 26235            1.0        EA             9.95            0.0         Amount
# 26236            1.0        EA           125.00            0.0         Amount
# 26237            1.0        EA            50.00            0.0         Amount
# 26238            1.0        EA             9.95            0.0         Amount
# 26239            1.0        EA            19.95            0.0         Amount
# 26240            1.0        EA             9.95            0.0         Amount
# 26241            2.0        EA             5.95            0.0         Amount
# 26242            2.0      EACH            14.95            0.0         Amount
# 26243            1.0      EACH           195.00            0.0         Amount
# 26244            1.0      Each            17.00            0.0         Amount
# 26245            1.0        ea            75.00            0.0         Amount
# 26246            1.0  No Units           240.15            0.0         Amount
#
#                    Ship Via   Amount
# 16710               Unknown  -145.00
# 17298  Request FREIGHT or I    25.30
# 17299  Request FREIGHT or I    49.25
# 17300  Request FREIGHT or I    50.00
# 17301  Request FREIGHT or I  1200.00
# 17302  Request FREIGHT or I    68.00
# 17303  Request FREIGHT or I   440.00
# 17304  Request FREIGHT or I    45.00
# 17305  Request FREIGHT or I    65.00
# 17306  Request FREIGHT or I     0.00
# 17307  Request FREIGHT or I     3.00
# 17308  Request FREIGHT or I   100.00
# 17309  Request FREIGHT or I   430.00
# 26233               Unknown     6.90
# 26234               Unknown     7.29
# 26235               Unknown     9.95
# 26236               Unknown   125.00
# 26237               Unknown    50.00
# 26238               Unknown     9.95
# 26239               Unknown    19.95
# 26240               Unknown     9.95
# 26241               Unknown    11.90
# 26242               Unknown    29.90
# 26243               Unknown   195.00
# 26244               Unknown    17.00
# 26245               Unknown    75.00
# 26246               Unknown   240.15

# %% [markdown]
# **Adding regions for Bloomington, Evansville, and Esperance**

# %%
data.loc[((data['Ship To Region'].isna()) & (data['Ship To City'] == 'Bloomington')), 'Ship To Region'] = 'IN'

data.loc[((data['Ship To Region'].isna()) & (data['Ship To City'] == 'Evansville')), 'Ship To Region'] = 'IN'

data.loc[((data['Ship To Region'].isna()) & (data['Ship To Country'] == 'USA') & (data['Ship To City'] == 'esperance')), 'Ship To Region'] = 'WA'

# %%
data[data['Transaction ID'] == '00179220']

#great, this worked
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 16710    Line Item       00179220      Credit Memo     bea0047    esperance
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 16710             WA             USA       2021-07-21    2021-07-21
#
#              Item ID Drop Ship Location ID Product Line  Qty Ship Sell Units  \
# 16710  sublined item         N         B01      service           -1.0    ea
#
#        Unit Price Sell  Price Adj Pct Price Adj Type Ship Via  Amount
# 16710            145.0            0.0        Percent  Unknown  -145.0

# %%
#looking through orders that have USA as shipping country but NaN Region.
data[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna())]
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 13163    Line Item       00179698          Invoice     suz0056          NaN
# 13164    Sales Tax       00179698          Invoice     suz0056          NaN
# 14067    Line Item       00179569          Invoice     dav0534          NaN
# 14068    Line Item       00179569          Invoice     dav0534          NaN
# 14069    Line Item       00179569          Invoice     dav0534          NaN
# ...            ...            ...              ...         ...          ...
# 41079    Line Item       00175502          Invoice     rus0049          NaN
# 41080    Line Item       00175502          Invoice     rus0049          NaN
# 41081    Line Item       00175502          Invoice     rus0049          NaN
# 41082    Line Item       00175502          Invoice     rus0049          NaN
# 41083    Sales Tax       00175502          Invoice     rus0049          NaN
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 13163            NaN             USA       2021-08-19    2021-08-19
# 13164            NaN             USA       2021-08-19    2021-08-19
# 14067            NaN             USA       2021-08-12    2021-08-12
# 14068            NaN             USA       2021-08-12    2021-08-12
# 14069            NaN             USA       2021-08-12    2021-08-12
# ...              ...             ...              ...           ...
# 41079            NaN             USA       2021-02-12    2021-02-12
# 41080            NaN             USA       2021-02-12    2021-02-12
# 41081            NaN             USA       2021-02-12    2021-02-12
# 41082            NaN             USA       2021-02-12           NaT
# 41083            NaN             USA       2021-02-12    2021-02-12
#
#                    Item ID Drop Ship Location ID     Product Line  \
# 13163       Glassseparator         N         B01     Kiln Accesso
# 13164           No Item ID         N         B01  No Product Line
# 14067              GLOa1lb         N         B01      GLOW POWDER
# 14068          DH20HOLETIP         N         B01     National Com
# 14069  BB-BoroBatch-Shorts         N         B01       Boro Batch
# ...                    ...       ...         ...              ...
# 41079           glasscuttr         N         B01     CUTTING TOOL
# 41080            246190250         N         B01     Simax Tubing
# 41081            246190320         N         B01     Simax Tubing
# 41082              854-399         N         B01     CUTTING TOOL
# 41083           No Item ID         N         B01  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 13163            1.0        EA            7.784            0.0        Percent
# 13164            1.0  No Units            0.540            0.0         Amount
# 14067            1.0       5GR            5.000            0.0        Percent
# 14068            1.0      each           50.000            0.0        Percent
# 14069            1.0        LB           15.000            0.0        Percent
# ...              ...       ...              ...            ...            ...
# 41079            1.0      EACH           15.950            0.0        Percent
# 41080            1.0        PC            6.343            0.0        Percent
# 41081            1.0        PC            7.766            0.0        Percent
# 41082            0.0        EA           54.950            0.0        Percent
# 41083            1.0  No Units            2.100            0.0         Amount
#
#                Ship Via  Amount
# 13163           Unknown    7.78
# 13164           Unknown    0.54
# 14067  Pick Up Thursday    5.00
# 14068  Pick Up Thursday   50.00
# 14069  Pick Up Thursday   15.00
# ...                 ...     ...
# 41079           Pick Up   15.95
# 41080           Pick Up    6.34
# 41081           Pick Up    7.77
# 41082           Pick Up    0.00
# 41083           Pick Up    2.10
#
# [74 rows x 20 columns]

# %%
#so any order with sales tax here is a pick up order. All the orders above have Sales Tax, so the City and Region can be set to Bloomington, IN
data.loc[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna()), 'Ship To City'] = 'Bloomington'

data.loc[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna()), 'Ship To Region'] = 'Indiana'

# %%
#this is confirming that the remaining NaN regions in the data is in foreign countries and therefore do not need this information
data[data['Ship To Region'].isna()]['Ship To Country'].value_counts()
# Out:
# JPN       283
# DEU       217
# FRA       137
# GBR        80
# ITA        41
# AUS        35
# MEX        32
# FRANCE     27
# THA        25
# CHL        24
# ARG        14
# NZL        12
# BEL        11
# IRL        10
# JAPAN       7
# CHN         4
# IND         3
# CHE         2
# Name: Ship To Country, dtype: int64

# %%
#looing at the remaining NaN cities
data[data['Ship To City'].isna()]
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 0          Payment       00205712          Payment     bet0095          NaN
# 1          Payment       00204681          Payment     Tod0111          NaN
# 2          Payment       00205719          Payment     chr0867          NaN
# 3          Payment       00205734          Payment     col0265          NaN
# 4          Payment       00205720          Payment     jen0078          NaN
# ...            ...            ...              ...         ...          ...
# 48702      Payment       00191080          Payment     ada0153          NaN
# 48703      Payment       00191078          Payment     die0005          NaN
# 48869      Payment       00191070          Payment     ran0051          NaN
# 48870      Payment       00191077          Payment     nic0216          NaN
# 48871      Payment       00191102          Payment     cha0637          NaN
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 0                NaN             NaN       2021-12-01           NaT
# 1                NaN             NaN       2021-12-01           NaT
# 2                NaN             NaN       2021-12-01           NaT
# 3                NaN             NaN       2021-12-01           NaT
# 4                NaN             NaN       2021-12-01           NaT
# ...              ...             ...              ...           ...
# 48702            NaN             NaN       2021-01-02           NaT
# 48703            NaN             NaN       2021-01-02           NaT
# 48869            NaN             NaN       2021-01-02           NaT
# 48870            NaN             NaN       2021-01-01           NaT
# 48871            NaN             NaN       2021-01-01           NaT
#
#           Item ID Drop Ship Location ID     Product Line  Qty Ship Sell  \
# 0      No Item ID         N         NaN  No Product Line            0.0
# 1      No Item ID         N         NaN  No Product Line            0.0
# 2      No Item ID         N         NaN  No Product Line            0.0
# 3      No Item ID         N         NaN  No Product Line            0.0
# 4      No Item ID         N         NaN  No Product Line            0.0
# ...           ...       ...         ...              ...            ...
# 48702  No Item ID         N         NaN  No Product Line            0.0
# 48703  No Item ID         N         NaN  No Product Line            0.0
# 48869  No Item ID         N         NaN  No Product Line            0.0
# 48870  No Item ID         N         NaN  No Product Line            0.0
# 48871  No Item ID         N         NaN  No Product Line            0.0
#
#           Units  Unit Price Sell  Price Adj Pct Price Adj Type Ship Via  \
# 0      No Units              0.0            0.0         Amount  Unknown
# 1      No Units              0.0            0.0         Amount  Unknown
# 2      No Units              0.0            0.0         Amount  Unknown
# 3      No Units              0.0            0.0         Amount  Unknown
# 4      No Units              0.0            0.0         Amount  Unknown
# ...         ...              ...            ...            ...      ...
# 48702  No Units              0.0            0.0         Amount  Unknown
# 48703  No Units              0.0            0.0         Amount  Unknown
# 48869  No Units              0.0            0.0         Amount  Unknown
# 48870  No Units              0.0            0.0         Amount  Unknown
# 48871  No Units              0.0            0.0         Amount  Unknown
#
#         Amount
# 0      -100.79
# 1      -620.62
# 2       -74.09
# 3      -400.04
# 4      -128.90
# ...        ...
# 48702  -265.24
# 48703  -798.49
# 48869 -1592.50
# 48870 -1076.35
# 48871   -52.72
#
# [5534 rows x 20 columns]

# %%
# for Transaction ID 0018138, looked in Traverse and the city is Atlanta, will change this
data.loc[(data['Transaction ID'] == '00181389'), 'Ship To City'] = 'Atlanta'

# %% [markdown]
# **removing History type of Payment**

# %%
data = data.loc[(data['History Type'] != 'Payment')]

# %% [markdown]
# ## Great! I believe this data is ready for Visualization. will write to a file

# %%
data.to_csv('ABR Imagery 2021 Orders.csv', index = False)
