# %% [markdown]
# # Preparing ABR Imagery 2021 Data for Analysis

# %% [markdown]
# **Will be focusing on SO Detail History View**

# %%
#import packages
import pandas as pd
import numpy as np
from datetime import datetime
from os import devnull
import xlrd

# %%
#since SO Detail History View is in .Xls format, will need to use devnull and xlrd to open
wb = xlrd.open_workbook('SO Detail History View 2021.Xls', logfile = open(devnull, 'w'))
data = pd.read_excel(wb, thousands = ',')

# %% [markdown]
# ## **Filtering to keep orders MADE in 2021**

# %%
#making transaction date and Actu Ship Date  datetime objects
data['Transaction Date'] = pd.to_datetime(data['Transaction Date'], format = "%m/%d/%Y")
data['Act Ship Date'] = pd.to_datetime(data['Act Ship Date'], format = "%m/%d/%Y")

# %%
#filtering data made in 2021
data= data[(data['Transaction Date'] >= '2021-01-01') & (data['Transaction Date'] <= '2021-12-31')]

# %%
#testing to see that it worked, great it does!
print(data['Transaction Date'].min())
print(data['Transaction Date'].max())
# Out:
# 2021-01-01 00:00:00
# 2021-12-30 00:00:00

# %% [markdown]
# # Changing type of Transaction ID to string and formating to match Traverse

# %%
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'float'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : 'int'})
data['Transaction ID'] = data['Transaction ID'].astype({'Transaction ID' : str})

# %%
data['Transaction ID'] = data['Transaction ID'].apply(lambda x: x.zfill(8))

# %%
data.head()
#sucessful
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00207311     hun0016       2021-12-30           NaT
# 1      Payment       00207321     lid0001       2021-12-30           NaT
# 2      Payment       00207309     rob0274       2021-12-30           NaT
# 3      Payment       00207315     jac0117       2021-12-30           NaT
# 4      Payment       00207318     max0010       2021-12-30           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -380.94
# 1      NaN -325.40
# 2      NaN -703.84
# 3      NaN  -89.53
# 4      NaN  -34.78

# %% [markdown]
# ## Filtering out Customer ID's that are not actually customers

# %%
customer_id_filter = ['edr0001','plt0001','Jos0118','Mag0003', 'PDK0001', 'isg0001']
data = data[~data['Customer ID'].isin(customer_id_filter)]

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00207311     hun0016       2021-12-30           NaT
# 1      Payment       00207321     lid0001       2021-12-30           NaT
# 2      Payment       00207309     rob0274       2021-12-30           NaT
# 3      Payment       00207315     jac0117       2021-12-30           NaT
# 4      Payment       00207318     max0010       2021-12-30           NaT
#
#   Transaction Type Description Item ID Location ID Price Code  Qty Ship Sell  \
# 0          Payment         NaN     NaN         NaN        NaN            0.0
# 1          Payment         NaN     NaN         NaN        NaN            0.0
# 2          Payment         NaN     NaN         NaN        NaN            0.0
# 3          Payment         NaN     NaN         NaN        NaN            0.0
# 4          Payment         NaN     NaN         NaN        NaN            0.0
#
#   Units   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  \
# 0    NaN              0.0            0.0         Amount             0.0
# 1    NaN              0.0            0.0         Amount             0.0
# 2    NaN              0.0            0.0         Amount             0.0
# 3    NaN              0.0            0.0         Amount             0.0
# 4    NaN              0.0            0.0         Amount             0.0
#
#   Ship Via  Amount
# 0      NaN -380.94
# 1      NaN -325.40
# 2      NaN -703.84
# 3      NaN  -89.53
# 4      NaN  -34.78

# %% [markdown]
# ## Saving unique items to text file to view them for any items that should't be there

# %%
np.savetxt('unique items 2021.txt', data['Item ID'].unique(), fmt='%s')

# %% [markdown]
# **All the items look good**

# %% [markdown]
# # There are many items with no Price Code, there is another alternative to use called Product Line. Will add this to the table replacing Price Code. Will check Product Line's and make sure all items have Product Lines

# %% [markdown]
# **In Traverse, got a list of all the items called 'IN Item View ALL.Xls'. This has the column called Product Line that we want. I will load this in and join with data on 'Item ID'**

# %%
#loading items
wb = xlrd.open_workbook('IN Item View ALL.Xls', logfile = open(devnull, 'w'))
items = pd.read_excel(wb)

# %%
#filtering to have only item id and prodcut lin
items = items[['Item ID', 'Product Line', 'Additional Description']]

# %%
items.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15646 entries, 0 to 15645
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Item ID                 15646 non-null  object
#  1   Product Line            15628 non-null  object
#  2   Additional Description  15467 non-null  object
# dtypes: object(3)
# memory usage: 366.8+ KB

# %%
#if there are any duplicated Items, they must be removed, this is so the join will not duplicated item ids for the orders
items.loc[(items['Item ID'].duplicated())]
# Out:
#        Item ID  Product Line  \
# 31     0041012  MORETTI TRAN
# 33     0041415  MORETTI TRAN
# 35       00456  MORETTI TRAN
# 355    1556008  MORETTI TRAN
# 357    1556012  MORETTI TRAN
# ...        ...           ...
# 15617      YTC  Asian Colore
# 15624    YTC32  Asian Colore
# 15626    YTC38  Asian Colore
# 15629    YTC44  Asian Colore
# 15631    YTC50  Asian Colore
#
#                                   Additional Description
# 31     This crystal-clear Moretti soft glass rod is 1...
# 33     This crystal-clear Moretti soft glass rod is 1...
# 35     This crystal-clear Moretti soft glass rod is 5...
# 355    Amber Pale Moretti Color Rod 104coe.   Availab...
# 357    Amber Light Moretti Color Rod 104coe.   Availa...
# ...                                                  ...
# 15617  This transparent dark amber yellow tubing is m...
# 15624  This transparent dark amber yellow tubing is m...
# 15626  This transparent dark amber yellow tubing is m...
# 15629  This transparent dark amber yellow tubing is m...
# 15631  This transparent dark amber yellow tubing is m...
#
# [1336 rows x 3 columns]

# %%
items.drop_duplicates(subset = 'Item ID', inplace = True)

# %%
#joining items with data
data = data.merge(items, on = 'Item ID', how = 'left')

# %%
data[data['Transaction ID'] == '00178603']
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 24955    Line Item       00178603     jas0097       2021-06-15    2021-06-16
# 24956    Line Item       00178603     jas0097       2021-06-15    2021-06-16
# 24957      Freight       00178603     jas0097       2021-06-15    2021-06-16
#
#       Transaction Type                          Description Item ID  \
# 24955          Invoice    Asian 25.4mm x 4.0mm Clear Tubing  AT2540
# 24956          Invoice  Asian 16mmx2.5mm-3.2mm Clear Tubing  AT1632
# 24957          Invoice                                  NaN     NaN
#
#       Location ID  Price Code  Qty Ship Sell Units   Unit Price Sell  \
# 24955         B01  ASIAN GLAS            1.0     CS            124.0
# 24956         B01  ASIAN GLAS            1.0     CS             80.0
# 24957         B01         NaN            1.0    NaN            125.0
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via  Amount  \
# 24955            0.0        Percent           6.634      NaN   124.0
# 24956            0.0        Percent          15.743      NaN    80.0
# 24957            0.0         Amount           0.000      NaN   125.0
#
#       Product Line                             Additional Description
# 24955   ASIAN TUBE  This economically priced borosilicate glass tu...
# 24956   ASIAN TUBE  This economically priced borosilicate glass tu...
# 24957          NaN                                                NaN

# %%
#removing Price code
del data['Price Code']

# %%
#reordering dataframe
data = data[['History Type','Transaction ID','Customer ID','Transaction Date','Act Ship Date','Transaction Type', 'Description','Additional Description','Item ID',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units ','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#renaming units to remove whitespace
data = data.rename(columns = {'Units ': 'Units'})

# %%
data.head()
# Out:
#   History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0      Payment       00207311     hun0016       2021-12-30           NaT
# 1      Payment       00207321     lid0001       2021-12-30           NaT
# 2      Payment       00207309     rob0274       2021-12-30           NaT
# 3      Payment       00207315     jac0117       2021-12-30           NaT
# 4      Payment       00207318     max0010       2021-12-30           NaT
#
#   Transaction Type Description Additional Description Item ID Location ID  \
# 0          Payment         NaN                    NaN     NaN         NaN
# 1          Payment         NaN                    NaN     NaN         NaN
# 2          Payment         NaN                    NaN     NaN         NaN
# 3          Payment         NaN                    NaN     NaN         NaN
# 4          Payment         NaN                    NaN     NaN         NaN
#
#   Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 0          NaN            0.0   NaN              0.0            0.0
# 1          NaN            0.0   NaN              0.0            0.0
# 2          NaN            0.0   NaN              0.0            0.0
# 3          NaN            0.0   NaN              0.0            0.0
# 4          NaN            0.0   NaN              0.0            0.0
#
#   Price Adj Type  Unit Cost Sell Ship Via  Amount
# 0         Amount             0.0      NaN -380.94
# 1         Amount             0.0      NaN -325.40
# 2         Amount             0.0      NaN -703.84
# 3         Amount             0.0      NaN  -89.53
# 4         Amount             0.0      NaN  -34.78

# %%
#viewing unique items that have no Product Line
data['Item ID'][(data['History Type'] == 'Line Item') & (data['Product Line'].isna())].unique()   
#why didn't this give me ALL the product lines with nan and history type line item ?
# Out:
# array(['GasSaver-28b004', 'BB-ST-PinkLemonade', 'BB-ST-BlueMoonshine',
#        'purr-minor kit', nan, 'purr-glass pack', 'purr-bravo kit',
#        'claw11', 'purr-completeminor', 'jc-3m2fd-ac-4.5',
#        '854-203DSK-ADPT', 'Liftgatefee', 'JC-ST14', 'JC-ST19',
#        'BB-46-B-BROWNHONEY', 'sun', 'ind-3mc-b2', 'PORTABLECCASE2',
#        '0000-BOROBATCH-LOGO-2XL', 'crucible30lb',
#        '4-2-INLET-CONVERSIONKIT', 'Crucible-3inchby1.5inch',
#        'BEGINNERKIT-NORTELREDMAX', 'Purr-Bravo Kit', 'GORO3D', 'GORO5',
#        'GOS6W', 'VW1-01680', 'CLAW15', 'TUNGSTEN PICK 1/8', 'JC-1014B',
#        'OPAL POLISHED WHITE', 'BB-03-M-DAVESBLUES', '854-220k',
#        'ind-14/10f-hw', 'ind-1fc-b2'], dtype=object)

# %% [markdown]
# ### Adding Product Lines to Items with NaN Product Lines

# %% [markdown]
# **I have looked in Traverse for these Item ID's and have found their corresponding Product Line's. The only items that needed made Product Lines were crucible pots**

# %%
#replacing Prodcut lines
data.loc[(data['Item ID'] == 'LIftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'liftgatefee'), 'Product Line'] = 'service'
data.loc[(data['Item ID'] == 'Liftgatefee'), 'Product Line'] = 'service'

purr_list = ['purr-minor kit', 'purr-bravo kit', 'purr-glass pack', 'Purr-Bravo Kit']
data.loc[(data['Item ID'].isin(purr_list)), 'Product Line'] = 'PURR'

hose_list = ['4-2-INLET-CONVERSIONKIT', '854-203DSK-ADPT', '854-220k']
data.loc[(data['Item ID'].isin(hose_list)), 'Product Line'] = 'Hoses & Acce'

bb_list = ['BB-03-M-DAVESBLUES', 'BB-46-B-BROWNHONEY']
data.loc[(data['Item ID'].isin(bb_list)), 'Product Line'] = 'Boro Batch'

data.loc[(data['Item ID'] == 'BEGINNERKIT-NORTELREDMAX'), 'Product Line'] = 'BEGINNER KIT'

claw_list = ['claw11', 'CLAW15']
data.loc[(data['Item ID'].isin(claw_list)), 'Product Line'] = 'CLAWS'

crucible_list = ['crucible30lb', 'Crucible-3inchby1.5inch']
data.loc[(data['Item ID'].isin(crucible_list)), 'Product Line'] = 'CRUCIBLE'

opal_list = ['GORO3D', 'GORO5', 'GOS6W', 'OPAL POLISHED WHITE']
data.loc[(data['Item ID'].isin(opal_list)), 'Product Line'] = 'OPALS'

joints_list = ['ind-14/10f-hw', 'ind-1fc-b2', 'ind-3mc-b2', 'JC-ST14', 'JC-ST19']
data.loc[(data['Item ID'].isin(joints_list)), 'Product Line'] = 'Glass Joints'

bushings_list = ['JC-1014B', 'jc-3m2fd-ac-4.5']
data.loc[(data['Item ID'].isin(bushings_list)), 'Product Line'] = 'Bushings'

data.loc[(data['Item ID'].isin(['PORTABLECCASE2'])), 'Product Line'] = 'CRAFT ITEMS'

data.loc[(data['Item ID'].isin(['TUNGSTEN PICK 1/8'])), 'Product Line'] = 'RAKES/PICKS'

data.loc[(data['Item ID'].isin(['VW1-01680'])), 'Product Line'] = 'HA TOOLS'

data.loc[(data['Item ID'].isin(['0000-BOROBATCH-LOGO-2XL'])), 'Product Line'] = 'T-SHIRTS'
#dropping the row with 'sun' as the item id
data = data.drop(data.loc[data['Item ID'] == 'sun'].index)

# %%
#further exploring line items with nan product line
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Payment      6044
# Freight      4867
# Sales Tax     582
# Line Item      30
# Misc            1
# Name: History Type, dtype: int64

# %%
data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 32       Line Item       00182224     lid0001       2021-12-30    2021-12-30
# 301      Line Item       00182145     isa0034       2021-12-28    2021-12-28
# 303      Line Item       00182145     isa0034       2021-12-28    2021-12-28
# 1161     Line Item       00182032     him0001       2021-12-20           NaT
# 1667     Line Item       00181938     lew0003       2021-12-15    2021-12-15
# 2893     Line Item       00181791     lui0024       2021-12-07    2021-12-10
# 2894     Line Item       00181791     lui0024       2021-12-07           NaT
# 4629     Line Item       00181515     tom0001       2021-11-26    2021-11-30
# 5742     Line Item       00181356     pur0003       2021-11-18    2021-12-09
# 7491     Line Item       00181145     ste0474       2021-11-05           NaT
# 9434     Line Item       00180835     ian0020       2021-10-20    2021-10-20
# 12707    Line Item       00180338     dou0045       2021-09-23    2021-09-24
# 13361    Line Item       00180247     pau0049       2021-09-17    2021-09-20
# 16213    Line Item       00179869     pau0081       2021-08-26           NaT
# 18015    Line Item       00179578     Nor0008       2021-08-12           NaT
# 24589    Line Item       00178647     UOP0001       2021-06-17           NaT
# 24807    Line Item       00178609     ala0056       2021-06-16           NaT
# 25664    Line Item       00178439     mar1061       2021-06-09    2021-06-11
# 26456    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 26457    Line Item       00178332     KEN0143       2021-06-03    2021-06-03
# 29868    Line Item       00177763     mar1058       2021-05-11           NaT
# 33728    Line Item       00177171     ral0008       2021-04-15           NaT
# 35806    Line Item       00176832     gle0034       2021-04-04           NaT
# 38954    Line Item       00176402     nic0101       2021-03-17           NaT
# 38961    Line Item       00176403     mat0219       2021-03-17           NaT
# 41622    Line Item       00175870     pau0081       2021-03-01           NaT
# 44805    Line Item       00175485     bre0136       2021-02-11           NaT
# 44810    Line Item       00175482     ada0034       2021-02-11    2021-03-18
# 45130    Line Item       00175447     jam0021       2021-02-09           NaT
# 47509    Line Item       00175033     TGP0001       2021-01-25           NaT
#
#       Transaction Type                                        Description  \
# 32             Invoice                               Mechanical Gas Saver
# 301            Invoice                         BB Pink Lemonade Stringers
# 303            Invoice                        BB Blue Moonshine Stringers
# 1161           Invoice                                                NaN
# 1667           Invoice                                                NaN
# 2893           Invoice                                                NaN
# 2894           Invoice                                                NaN
# 4629           Invoice                                                NaN
# 5742           Invoice                         Complete Minor Starter Kit
# 7491           Invoice                                                NaN
# 9434           Invoice                                                NaN
# 12707          Invoice                                                NaN
# 13361          Invoice                                                NaN
# 16213          Invoice                                                NaN
# 18015          Invoice                                                NaN
# 24589          Invoice                                                NaN
# 24807          Invoice                                                NaN
# 25664          Invoice                                                NaN
# 26456      Credit Memo  tax credit he should not be charged tax he is ...
# 26457      Credit Memo                      refunded him tax he is exempt
# 29868          Invoice                                                NaN
# 33728          Invoice                                                NaN
# 35806          Invoice  subbed out 3 parramore rods with sage, seamist...
# 38954          Invoice                                                NaN
# 38961          Invoice                                                NaN
# 41622          Invoice                                                NaN
# 44805          Invoice                                                NaN
# 44810          Invoice                                                NaN
# 45130          Invoice                                                NaN
# 47509          Invoice                                                NaN
#
#                                   Additional Description              Item ID  \
# 32                                                   NaN      GasSaver-28b004
# 301                                                  NaN   BB-ST-PinkLemonade
# 303                                                  NaN  BB-ST-BlueMoonshine
# 1161                                                 NaN                  NaN
# 1667                                                 NaN                  NaN
# 2893                                                 NaN                  NaN
# 2894                                                 NaN                  NaN
# 4629                                                 NaN                  NaN
# 5742   Complete glass kit for a beginner-shipping inc...   purr-completeminor
# 7491                                                 NaN                  NaN
# 9434                                                 NaN                  NaN
# 12707                                                NaN                  NaN
# 13361                                                NaN                  NaN
# 16213                                                NaN                  NaN
# 18015                                                NaN                  NaN
# 24589                                                NaN                  NaN
# 24807                                                NaN                  NaN
# 25664                                                NaN                  NaN
# 26456                                                NaN                  NaN
# 26457                                                NaN                  NaN
# 29868                                                NaN                  NaN
# 33728                                                NaN                  NaN
# 35806                                                NaN                  NaN
# 38954                                                NaN                  NaN
# 38961                                                NaN                  NaN
# 41622                                                NaN                  NaN
# 44805                                                NaN                  NaN
# 44810                                                NaN                  NaN
# 45130                                                NaN                  NaN
# 47509                                                NaN                  NaN
#
#       Location ID Product Line  Qty Ship Sell  Units  Unit Price Sell  \
# 32            B01          NaN            1.0   EACH           209.95
# 301           B01          NaN            1.0     LB            94.20
# 303           B01          NaN            1.0  1/2lb            51.81
# 1161          B01          NaN            0.0     LB             0.00
# 1667          B01          NaN            1.0     LB             0.00
# 2893          B01          NaN            1.0     LB             0.00
# 2894          B01          NaN            0.0     LB            55.88
# 4629          B01          NaN            1.0     LB             0.00
# 5742          B01          NaN            1.0     ea          1600.00
# 7491          B01          NaN            0.0     LB             0.00
# 9434          B01          NaN            1.0     LB             0.00
# 12707         B01          NaN            1.0     LB             0.00
# 13361         B01          NaN            1.0     LB             0.00
# 16213         B01          NaN            0.0     LB             0.00
# 18015         B01          NaN            0.0     LB             0.00
# 24589         B01          NaN            0.0     LB             0.00
# 24807         B01          NaN            0.0     LB             0.00
# 25664         B01          NaN            1.0     LB             0.00
# 26456         B01          NaN           -1.0     LB             0.00
# 26457         B01          NaN            0.0     LB            40.15
# 29868         B01          NaN            0.0     LB             0.00
# 33728         B01          NaN            0.0     LB             0.00
# 35806         B01          NaN            0.0     LB             0.00
# 38954         B01          NaN            0.0     LB             0.00
# 38961         B01          NaN            0.0     LB             0.00
# 41622         B01          NaN            0.0     LB             0.00
# 44805         B01          NaN            0.0     LB             0.00
# 44810         B01          NaN            1.0     LB             0.00
# 45130         B01          NaN            0.0     LB             0.00
# 47509         B01          NaN            0.0     LB             0.00
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell              Ship Via  \
# 32               0.0         Amount          159.01                   GND
# 301              0.0         Amount            0.00                   GND
# 303              0.0         Amount            0.00                   GND
# 1161             0.0        Percent            0.00                   NaN
# 1667             0.0        Percent            0.00                   NaN
# 2893             0.0        Percent            0.00                   NaN
# 2894             0.0        Percent            0.00                   NaN
# 4629             0.0        Percent            0.00                   GND
# 5742             0.0        Percent         1181.55                   NaN
# 7491             0.0        Percent            0.00                   NaN
# 9434             0.0        Percent            0.00                   NaN
# 12707            0.0        Percent            0.00                   NaN
# 13361            0.0        Percent            0.00                   NaN
# 16213            0.0        Percent            0.00                   NaN
# 18015            0.0        Percent            0.00                   NaN
# 24589            0.0        Percent            0.00                   NaN
# 24807            0.0        Percent            0.00                   GND
# 25664            0.0        Percent            0.00                   NaN
# 26456            0.0        Percent            0.00                   NaN
# 26457            0.0        Percent            0.00                   NaN
# 29868            0.0        Percent            0.00                   GND
# 33728            0.0        Percent            0.00                   NaN
# 35806            0.0        Percent            0.00  International Econom
# 38954            0.0        Percent            0.00                   NaN
# 38961            0.0        Percent            0.00                   NaN
# 41622            0.0        Percent            0.00                   NaN
# 44805            0.0        Percent            0.00                   NaN
# 44810            0.0        Percent            0.00                   NaN
# 45130            0.0        Percent            0.00                   NaN
# 47509            0.0        Percent            0.00                   NaN
#
#         Amount
# 32      209.95
# 301      94.20
# 303      51.81
# 1161      0.00
# 1667      0.00
# 2893      0.00
# 2894      0.00
# 4629      0.00
# 5742   1600.00
# 7491      0.00
# 9434      0.00
# 12707     0.00
# 13361     0.00
# 16213     0.00
# 18015     0.00
# 24589     0.00
# 24807     0.00
# 25664     0.00
# 26456     0.00
# 26457     0.00
# 29868     0.00
# 33728     0.00
# 35806     0.00
# 38954     0.00
# 38961     0.00
# 41622     0.00
# 44805     0.00
# 44810     0.00
# 45130     0.00
# 47509     0.00

# %% [markdown]
# **Looking at the cell above, everything with practically all NaN is empty rows,  I know this by double checking the orders in Traverse, These rows can be removed.
# can remove Trans ID 00178332
# can remove index 41715, this is an emtpy line with information on items that were subbed out
# so everything from the table above can be removed from the dataset**

# %%
remove_index = data.loc[(data['Product Line'].isna()) & (data['History Type'] == 'Line Item')].index

data = data[~data.index.isin(remove_index)]

# %%
#no all the line items are dealt with
data.loc[(data['Product Line'].isna()), 'History Type'].value_counts()
# Out:
# Payment      6044
# Freight      4867
# Sales Tax     582
# Misc            1
# Name: History Type, dtype: int64

# %%
#looking at the miscallaneuous item in Traverse, this item needs to stay as it counts to what the customer paid
data.loc[(data['History Type'] == 'Misc')]

#need to keep the Freight and Sales Tax rows as well, this gives important information and these should not have a product line. in the future on this project, I may
# add product lines for these for help on getting totals for these categories, but for now, I will not put a Product Line on these
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 14155         Misc       00180135     sam0076       2021-09-10    2021-09-10
#
#       Transaction Type Description Additional Description Item ID Location ID  \
# 14155          Invoice         NaN                    NaN     NaN         B01
#
#       Product Line  Qty Ship Sell Units  Unit Price Sell  Price Adj Pct  \
# 14155          NaN            1.0   NaN            645.0            0.0
#
#       Price Adj Type  Unit Cost Sell Ship Via  Amount
# 14155         Amount             0.0      NaN   645.0

# %%
#changing dtypes of the data for values that should be numeric
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51764 entries, 0 to 51794
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            51764 non-null  object
#  1   Transaction ID          51764 non-null  object
#  2   Customer ID             51764 non-null  object
#  3   Transaction Date        51764 non-null  datetime64[ns]
#  4   Act Ship Date           44353 non-null  datetime64[ns]
#  5   Transaction Type        51764 non-null  object
#  6   Description             40212 non-null  object
#  7   Additional Description  29621 non-null  object
#  8   Item ID                 40270 non-null  object
#  9   Location ID             45720 non-null  object
#  10  Product Line            40270 non-null  object
#  11  Qty Ship Sell           51764 non-null  float64
#  12  Units                   40270 non-null  object
#  13  Unit Price Sell         51764 non-null  float64
#  14  Price Adj Pct           51764 non-null  float64
#  15  Price Adj Type          51764 non-null  object
#  16  Unit Cost Sell          51764 non-null  float64
#  17  Ship Via                35879 non-null  object
#  18  Amount                  51764 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(12)
# memory usage: 7.9+ MB

# %%
data['Qty Ship Sell'] = data['Qty Ship Sell'].astype({'Qty Ship Sell' : float})
data['Unit Price Sell'] = data['Unit Price Sell'].astype({'Unit Price Sell' : float})
data['Amount'] = data['Amount'].astype({'Amount' : float})

# %% [markdown]
# # Adding a Drop Ship column to the data.

# %% [markdown]
# **Some items are drop ship items, will add a column detailing whether a particular item is a drop ship item or not.  An item will be a drop ship item if "DROP SHIP" exists in the Additional Description**

# %%
#setting nan in additional Description to 'No Additional Description'
data['Additional Description'] = data['Additional Description'].fillna('No Additional Description')

# %%
data['Additional Description'].str.contains(pat = 'DROP SHIP')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51790    False
# 51791    False
# 51792    False
# 51793    False
# 51794    False
# Name: Additional Description, Length: 51764, dtype: bool

# %%
#adding column for whether an item is Drop ship 
data['Drop Ship'] = 0

# %%
#creatiing conditional for Drop ship column, will either be Y or N
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == True), 'Drop Ship'] = 'Y'
data.loc[(data['Additional Description'].str.contains(pat = 'DROP SHIP') == False), 'Drop Ship'] = 'N'

# %% [markdown]
# # Handling the rest of the NaN data in the dataset

# %%
data.isna().sum()
# Out:
# History Type                  0
# Transaction ID                0
# Customer ID                   0
# Transaction Date              0
# Act Ship Date              7411
# Transaction Type              0
# Description               11552
# Additional Description        0
# Item ID                   11494
# Location ID                6044
# Product Line              11494
# Qty Ship Sell                 0
# Units                     11494
# Unit Price Sell               0
# Price Adj Pct                 0
# Price Adj Type                0
# Unit Cost Sell                0
# Ship Via                  15885
# Amount                        0
# Drop Ship                     0
# dtype: int64

# %% [markdown]
# **for items that have NaT for actual shipping date, these are items that did not ship, will keep this NaT**

# %% [markdown]
# **Item ID, Product Line, and Units are all columns that do not have items, I will change these to 'No Item ID', 'No Product Line', 'No Units'**

# %%
data['Item ID'].fillna('No Item ID', inplace = True)
data['Product Line'].fillna('No Product Line', inplace = True)
data['Units'].fillna('No Units', inplace = True)

# %%
#for Ship via, the NaN values are unknown, so I will put 'unknown', this is because I would have to mainly go through over 10,000 entries to see what the shipping was
# in Traverse. And that is ridiculous
data.loc[(data['Ship Via'].isna())]
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0          Payment       00207311     hun0016       2021-12-30           NaT
# 1          Payment       00207321     lid0001       2021-12-30           NaT
# 2          Payment       00207309     rob0274       2021-12-30           NaT
# 3          Payment       00207315     jac0117       2021-12-30           NaT
# 4          Payment       00207318     max0010       2021-12-30           NaT
# ...            ...            ...         ...              ...           ...
# 51772    Line Item       00174470     die0005       2021-01-02    2021-01-11
# 51773      Freight       00174470     die0005       2021-01-02    2021-01-11
# 51792      Payment       00191070     ran0051       2021-01-02           NaT
# 51793      Payment       00191077     nic0216       2021-01-01           NaT
# 51794      Payment       00191102     cha0637       2021-01-01           NaT
#
#       Transaction Type           Description  \
# 0              Payment                   NaN
# 1              Payment                   NaN
# 2              Payment                   NaN
# 3              Payment                   NaN
# 4              Payment                   NaN
# ...                ...                   ...
# 51772          Invoice  Northstar Galaxy Rod
# 51773          Invoice                   NaN
# 51792          Payment                   NaN
# 51793          Payment                   NaN
# 51794          Payment                   NaN
#
#                                   Additional Description     Item ID  \
# 0                              No Additional Description  No Item ID
# 1                              No Additional Description  No Item ID
# 2                              No Additional Description  No Item ID
# 3                              No Additional Description  No Item ID
# 4                              No Additional Description  No Item ID
# ...                                                  ...         ...
# 51772  <h4> Item name: </h4>\n\nNorthstar Galaxy Rod ...       ns152
# 51773                          No Additional Description  No Item ID
# 51792                          No Additional Description  No Item ID
# 51793                          No Additional Description  No Item ID
# 51794                          No Additional Description  No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 0             NaN  No Product Line            0.0  No Units              0.0
# 1             NaN  No Product Line            0.0  No Units              0.0
# 2             NaN  No Product Line            0.0  No Units              0.0
# 3             NaN  No Product Line            0.0  No Units              0.0
# 4             NaN  No Product Line            0.0  No Units              0.0
# ...           ...              ...            ...       ...              ...
# 51772         B01     Northstar Ro            2.0        LB             58.5
# 51773         B01  No Product Line            1.0  No Units            240.0
# 51792         NaN  No Product Line            0.0  No Units              0.0
# 51793         NaN  No Product Line            0.0  No Units              0.0
# 51794         NaN  No Product Line            0.0  No Units              0.0
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via   Amount  \
# 0                0.0         Amount             0.0      NaN  -380.94
# 1                0.0         Amount             0.0      NaN  -325.40
# 2                0.0         Amount             0.0      NaN  -703.84
# 3                0.0         Amount             0.0      NaN   -89.53
# 4                0.0         Amount             0.0      NaN   -34.78
# ...              ...            ...             ...      ...      ...
# 51772            0.0         Amount            32.5      NaN   117.00
# 51773            0.0         Amount             0.0      NaN   240.00
# 51792            0.0         Amount             0.0      NaN -1592.50
# 51793            0.0         Amount             0.0      NaN -1076.35
# 51794            0.0         Amount             0.0      NaN   -52.72
#
#       Drop Ship
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 51772         N
# 51773         N
# 51792         N
# 51793         N
# 51794         N
#
# [15885 rows x 20 columns]

# %%
#replacing ship via nan with unknown
data['Ship Via'].fillna('Unknown', inplace = True)

# %%
#Replacing Description NaN with 'No Description'
data['Description'].fillna('No Description', inplace = True)

# %%
#Great, that handles all the NaN data!
data.isna().sum()
# Out:
# History Type                 0
# Transaction ID               0
# Customer ID                  0
# Transaction Date             0
# Act Ship Date             7411
# Transaction Type             0
# Description                  0
# Additional Description       0
# Item ID                      0
# Location ID               6044
# Product Line                 0
# Qty Ship Sell                0
# Units                        0
# Unit Price Sell              0
# Price Adj Pct                0
# Price Adj Type               0
# Unit Cost Sell               0
# Ship Via                     0
# Amount                       0
# Drop Ship                    0
# dtype: int64

# %%
data
# Out:
#       History Type Transaction ID Customer ID Transaction Date Act Ship Date  \
# 0          Payment       00207311     hun0016       2021-12-30           NaT
# 1          Payment       00207321     lid0001       2021-12-30           NaT
# 2          Payment       00207309     rob0274       2021-12-30           NaT
# 3          Payment       00207315     jac0117       2021-12-30           NaT
# 4          Payment       00207318     max0010       2021-12-30           NaT
# ...            ...            ...         ...              ...           ...
# 51790    Line Item       00174473     ada0153       2021-01-02    2021-01-11
# 51791      Freight       00174473     ada0153       2021-01-02    2021-01-11
# 51792      Payment       00191070     ran0051       2021-01-02           NaT
# 51793      Payment       00191077     nic0216       2021-01-01           NaT
# 51794      Payment       00191102     cha0637       2021-01-01           NaT
#
#       Transaction Type                     Description  \
# 0              Payment                  No Description
# 1              Payment                  No Description
# 2              Payment                  No Description
# 3              Payment                  No Description
# 4              Payment                  No Description
# ...                ...                             ...
# 51790          Invoice  Y-Splitter w/ Valves (Propane)
# 51791          Invoice                  No Description
# 51792          Payment                  No Description
# 51793          Payment                  No Description
# 51794          Payment                  No Description
#
#                                   Additional Description     Item ID  \
# 0                              No Additional Description  No Item ID
# 1                              No Additional Description  No Item ID
# 2                              No Additional Description  No Item ID
# 3                              No Additional Description  No Item ID
# 4                              No Additional Description  No Item ID
# ...                                                  ...         ...
# 51790     Propane Y with Valves on Each Side: for use...         YPV
# 51791                          No Additional Description  No Item ID
# 51792                          No Additional Description  No Item ID
# 51793                          No Additional Description  No Item ID
# 51794                          No Additional Description  No Item ID
#
#       Location ID     Product Line  Qty Ship Sell     Units  Unit Price Sell  \
# 0             NaN  No Product Line            0.0  No Units             0.00
# 1             NaN  No Product Line            0.0  No Units             0.00
# 2             NaN  No Product Line            0.0  No Units             0.00
# 3             NaN  No Product Line            0.0  No Units             0.00
# 4             NaN  No Product Line            0.0  No Units             0.00
# ...           ...              ...            ...       ...              ...
# 51790         B01     Hoses & Acce            1.0        EA            39.95
# 51791         B01  No Product Line            1.0  No Units            26.45
# 51792         NaN  No Product Line            0.0  No Units             0.00
# 51793         NaN  No Product Line            0.0  No Units             0.00
# 51794         NaN  No Product Line            0.0  No Units             0.00
#
#        Price Adj Pct Price Adj Type  Unit Cost Sell Ship Via   Amount  \
# 0                0.0         Amount           0.000  Unknown  -380.94
# 1                0.0         Amount           0.000  Unknown  -325.40
# 2                0.0         Amount           0.000  Unknown  -703.84
# 3                0.0         Amount           0.000  Unknown   -89.53
# 4                0.0         Amount           0.000  Unknown   -34.78
# ...              ...            ...             ...      ...      ...
# 51790            0.0         Amount          20.908      GND    39.95
# 51791            0.0         Amount           0.000      GND    26.45
# 51792            0.0         Amount           0.000  Unknown -1592.50
# 51793            0.0         Amount           0.000  Unknown -1076.35
# 51794            0.0         Amount           0.000  Unknown   -52.72
#
#       Drop Ship
# 0             N
# 1             N
# 2             N
# 3             N
# 4             N
# ...         ...
# 51790         N
# 51791         N
# 51792         N
# 51793         N
# 51794         N
#
# [51764 rows x 20 columns]

# %%
#restructuring data
data = data[['History Type','Transaction ID','Transaction Type','Customer ID','Transaction Date','Act Ship Date', 'Description','Additional Description','Item ID', 'Drop Ship',
             'Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
#resetting index
data.reset_index(drop = True, inplace = True)

# %% [markdown]
# # Adding geographic information to orders

# %% [markdown]
# **I have made a file from Traverse with the Shipping Information for the Orders in this dataset, the file is 'AR Transaction View ALL.Xls'. I will load this data in and join to the main dataset on Transaction ID**

# %%
#importing Customer address
wb = xlrd.open_workbook('AR Transaction History View ALL.Xls', logfile = open(devnull, 'w'))
customer_data = pd.read_excel(wb)

# %%
customer_data.head()
# Out:
#   Customer ID  Transaction ID Transaction Type  Invoice Number  Ship To City  \
# 0     lid0001          182224          Invoice          121123     Paramount
# 1     max0010          182220          Invoice          121119   Bloomington
# 2     jen0510          182219          Invoice          121117      Sarasota
# 3     jac0117          182218          Invoice          121120      PLYMOUTH
# 4     mic0628          182217          Invoice          121118  Philadelphia
#
#           Ship Number Ship To Region Ship To Country Invoice Date  \
# 0  1ZR37F900342122004             CA             USA   12/30/2021
# 1                 NaN             IN             USA   12/30/2021
# 2  1ZR37F900341686952             FL             USA   12/30/2021
# 3  1ZR37F900341238776             IN             USA   12/30/2021
# 4  1ZR37F900341823160             PA             USA   12/30/2021
#
#   Total Payment Amount Total Cost     Total
# 0               325.40     207.51    325.40
# 1                34.78       6.50     34.78
# 2               175.36     110.00    175.36
# 3                89.53      16.70     89.53
# 4             4,069.00   3,041.82  4,069.00

# %%
#changing Transaction ID to fit Traverse format
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : 'float'})
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : 'int'})
customer_data['Transaction ID'] = customer_data['Transaction ID'].astype({'Transaction ID' : str})
customer_data['Transaction ID'] = customer_data['Transaction ID'].apply(lambda x: x.zfill(8))

# %%
#only need Customer ID, city, region and country
customer_data = customer_data[['Transaction ID', 'Ship To City', 'Ship To Region', 'Ship To Country']]

# %%
data.columns
# Out:
# Index(['History Type', 'Transaction ID', 'Transaction Type', 'Customer ID',
#        'Transaction Date', 'Act Ship Date', 'Description',
#        'Additional Description', 'Item ID', 'Drop Ship', 'Location ID',
#        'Product Line', 'Qty Ship Sell', 'Units', 'Unit Price Sell',
#        'Price Adj Pct', 'Price Adj Type', 'Unit Cost Sell', 'Ship Via',
#        'Amount'],
#       dtype='object')

# %%
#joining customer data with data
data = data.merge(customer_data, on = 'Transaction ID', how = 'left')

# %%
data = data[['History Type','Transaction ID', 'Transaction Type', 'Customer ID', 'Ship To City', 'Ship To Region', 'Ship To Country', 'Transaction Date','Act Ship Date',
             'Description', 'Additional Description','Item ID', 'Drop Ship','Location ID', 'Product Line','Qty Ship Sell', 'Units','Unit Price Sell', 'Price Adj Pct', 
             'Price Adj Type', 'Unit Cost Sell', 'Ship Via', 'Amount']]

# %%
data.head()
# Out:
#   History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 0      Payment       00207311          Payment     hun0016          NaN
# 1      Payment       00207321          Payment     lid0001          NaN
# 2      Payment       00207309          Payment     rob0274          NaN
# 3      Payment       00207315          Payment     jac0117          NaN
# 4      Payment       00207318          Payment     max0010          NaN
#
#   Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 0            NaN             NaN       2021-12-30           NaT
# 1            NaN             NaN       2021-12-30           NaT
# 2            NaN             NaN       2021-12-30           NaT
# 3            NaN             NaN       2021-12-30           NaT
# 4            NaN             NaN       2021-12-30           NaT
#
#       Description  ... Location ID     Product Line Qty Ship Sell     Units  \
# 0  No Description  ...         NaN  No Product Line           0.0  No Units
# 1  No Description  ...         NaN  No Product Line           0.0  No Units
# 2  No Description  ...         NaN  No Product Line           0.0  No Units
# 3  No Description  ...         NaN  No Product Line           0.0  No Units
# 4  No Description  ...         NaN  No Product Line           0.0  No Units
#
#   Unit Price Sell  Price Adj Pct Price Adj Type  Unit Cost Sell  Ship Via  \
# 0             0.0            0.0         Amount             0.0   Unknown
# 1             0.0            0.0         Amount             0.0   Unknown
# 2             0.0            0.0         Amount             0.0   Unknown
# 3             0.0            0.0         Amount             0.0   Unknown
# 4             0.0            0.0         Amount             0.0   Unknown
#
#    Amount
# 0 -380.94
# 1 -325.40
# 2 -703.84
# 3  -89.53
# 4  -34.78
#
# [5 rows x 23 columns]

# %% [markdown]
# ## Unit Cost Sell is a disaster.
#
# ## There are items with no unit cost sell, items with unit cost sell above unit price sell, and items with unit cost sell = unit price sell, this data is not useable in its current state.
#
# ## I could try to do a reasonable estimation on the unit cost sell, but it would be just that, an estimation. I may do this in the future, but for now I want to work with data that has been validated and known to be correct, not guesses

# %%
data.loc[(data['Unit Cost Sell'] >= data['Unit Price Sell'])].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13242 entries, 0 to 52961
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   History Type            13242 non-null  object
#  1   Transaction ID          13242 non-null  object
#  2   Transaction Type        13242 non-null  object
#  3   Customer ID             13242 non-null  object
#  4   Ship To City            7202 non-null   object
#  5   Ship To Region          7098 non-null   object
#  6   Ship To Country         7215 non-null   object
#  7   Transaction Date        13242 non-null  datetime64[ns]
#  8   Act Ship Date           6793 non-null   datetime64[ns]
#  9   Description             13242 non-null  object
#  10  Additional Description  13242 non-null  object
#  11  Item ID                 13242 non-null  object
#  12  Drop Ship               13242 non-null  object
#  13  Location ID             7198 non-null   object
#  14  Product Line            13242 non-null  object
#  15  Qty Ship Sell           13242 non-null  float64
#  16  Units                   13242 non-null  object
#  17  Unit Price Sell         13242 non-null  float64
#  18  Price Adj Pct           13242 non-null  float64
#  19  Price Adj Type          13242 non-null  object
#  20  Unit Cost Sell          13242 non-null  float64
#  21  Ship Via                13242 non-null  object
#  22  Amount                  13242 non-null  float64
# dtypes: datetime64[ns](2), float64(5), object(16)
# memory usage: 2.4+ MB

# %% [markdown]
# **removing unit cost sell from data. Can also remove Description and Additional Description as I have gotten the information that I needed from these columns**

# %%
del data['Unit Cost Sell']
del data['Description']
del data['Additional Description']

# %%
data
# Out:
#       History Type Transaction ID Transaction Type Customer ID  \
# 0          Payment       00207311          Payment     hun0016
# 1          Payment       00207321          Payment     lid0001
# 2          Payment       00207309          Payment     rob0274
# 3          Payment       00207315          Payment     jac0117
# 4          Payment       00207318          Payment     max0010
# ...            ...            ...              ...         ...
# 52957    Line Item       00174473          Invoice     ada0153
# 52958      Freight       00174473          Invoice     ada0153
# 52959      Payment       00191070          Payment     ran0051
# 52960      Payment       00191077          Payment     nic0216
# 52961      Payment       00191102          Payment     cha0637
#
#            Ship To City Ship To Region Ship To Country Transaction Date  \
# 0                   NaN            NaN             NaN       2021-12-30
# 1                   NaN            NaN             NaN       2021-12-30
# 2                   NaN            NaN             NaN       2021-12-30
# 3                   NaN            NaN             NaN       2021-12-30
# 4                   NaN            NaN             NaN       2021-12-30
# ...                 ...            ...             ...              ...
# 52957  Colorado Springs             CO             USA       2021-01-02
# 52958  Colorado Springs             CO             USA       2021-01-02
# 52959               NaN            NaN             NaN       2021-01-02
# 52960               NaN            NaN             NaN       2021-01-01
# 52961               NaN            NaN             NaN       2021-01-01
#
#       Act Ship Date     Item ID Drop Ship Location ID     Product Line  \
# 0               NaT  No Item ID         N         NaN  No Product Line
# 1               NaT  No Item ID         N         NaN  No Product Line
# 2               NaT  No Item ID         N         NaN  No Product Line
# 3               NaT  No Item ID         N         NaN  No Product Line
# 4               NaT  No Item ID         N         NaN  No Product Line
# ...             ...         ...       ...         ...              ...
# 52957    2021-01-11         YPV         N         B01     Hoses & Acce
# 52958    2021-01-11  No Item ID         N         B01  No Product Line
# 52959           NaT  No Item ID         N         NaN  No Product Line
# 52960           NaT  No Item ID         N         NaN  No Product Line
# 52961           NaT  No Item ID         N         NaN  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 0                0.0  No Units             0.00            0.0         Amount
# 1                0.0  No Units             0.00            0.0         Amount
# 2                0.0  No Units             0.00            0.0         Amount
# 3                0.0  No Units             0.00            0.0         Amount
# 4                0.0  No Units             0.00            0.0         Amount
# ...              ...       ...              ...            ...            ...
# 52957            1.0        EA            39.95            0.0         Amount
# 52958            1.0  No Units            26.45            0.0         Amount
# 52959            0.0  No Units             0.00            0.0         Amount
# 52960            0.0  No Units             0.00            0.0         Amount
# 52961            0.0  No Units             0.00            0.0         Amount
#
#       Ship Via   Amount
# 0      Unknown  -380.94
# 1      Unknown  -325.40
# 2      Unknown  -703.84
# 3      Unknown   -89.53
# 4      Unknown   -34.78
# ...        ...      ...
# 52957      GND    39.95
# 52958      GND    26.45
# 52959  Unknown -1592.50
# 52960  Unknown -1076.35
# 52961  Unknown   -52.72
#
# [52962 rows x 20 columns]

# %% [markdown]
# ## Looking at Address data that is NaN

# %%
data.isna().sum()
# Out:
# History Type           0
# Transaction ID         0
# Transaction Type       0
# Customer ID            0
# Ship To City        6107
# Ship To Region      7233
# Ship To Country     6027
# Transaction Date       0
# Act Ship Date       7911
# Item ID                0
# Drop Ship              0
# Location ID         6044
# Product Line           0
# Qty Ship Sell          0
# Units                  0
# Unit Price Sell        0
# Price Adj Pct          0
# Price Adj Type         0
# Ship Via               0
# Amount                 0
# dtype: int64

# %% [markdown]
# **So I only need Region information for orders made in the USA (since my visualizations for international orders will be at country level, not region level). So I will need to fill in the Regions in the USA that are empty**

# %%
data.loc[((data['Ship To Region'].isna()) & (data['Ship To Country'].isin(['USA', 'UNITED']))), ['Ship To City']].value_counts()
# Out:
# Ship To City
# Bloomington     88
# Evansville       6
# esperance        1
# dtype: int64

# %%
#Bloomington and Evansville are in the State of Indiana. going to explore esperance

# %%
data.loc[(data['Ship To City'] == 'esperance')]

#we are only interested with the City Esperance in the USA. Looking in Traverseon the Transaction ID 00179220, the state is WA
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 20800    Line Item       00179220      Credit Memo     bea0047    esperance
# 21388    Line Item       00179135          Invoice     bea0047    esperance
# 21389    Line Item       00179135          Invoice     bea0047    esperance
# 21390    Line Item       00179135          Invoice     bea0047    esperance
# 21391    Line Item       00179135          Invoice     bea0047    esperance
# 21392    Line Item       00179135          Invoice     bea0047    esperance
# 21393    Line Item       00179135          Invoice     bea0047    esperance
# 21394    Line Item       00179135          Invoice     bea0047    esperance
# 21395    Line Item       00179135          Invoice     bea0047    esperance
# 21396    Line Item       00179135          Invoice     bea0047    esperance
# 21397    Line Item       00179135          Invoice     bea0047    esperance
# 21398    Line Item       00179135          Invoice     bea0047    esperance
# 21399      Freight       00179135          Invoice     bea0047    esperance
# 30323    Line Item       00177781          Invoice     bea0047    esperance
# 30324    Line Item       00177781          Invoice     bea0047    esperance
# 30325    Line Item       00177781          Invoice     bea0047    esperance
# 30326    Line Item       00177781          Invoice     bea0047    esperance
# 30327    Line Item       00177781          Invoice     bea0047    esperance
# 30328    Line Item       00177781          Invoice     bea0047    esperance
# 30329    Line Item       00177781          Invoice     bea0047    esperance
# 30330    Line Item       00177781          Invoice     bea0047    esperance
# 30331    Line Item       00177781          Invoice     bea0047    esperance
# 30332    Line Item       00177781          Invoice     bea0047    esperance
# 30333    Line Item       00177781          Invoice     bea0047    esperance
# 30334    Line Item       00177781          Invoice     bea0047    esperance
# 30335    Line Item       00177781          Invoice     bea0047    esperance
# 30336      Freight       00177781          Invoice     bea0047    esperance
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 20800            NaN             USA       2021-07-21    2021-07-21
# 21388             WA             AUS       2021-07-16    2021-07-20
# 21389             WA             AUS       2021-07-16    2021-07-20
# 21390             WA             AUS       2021-07-16    2021-07-20
# 21391             WA             AUS       2021-07-16    2021-07-20
# 21392             WA             AUS       2021-07-16    2021-07-20
# 21393             WA             AUS       2021-07-16    2021-07-20
# 21394             WA             AUS       2021-07-16    2021-07-20
# 21395             WA             AUS       2021-07-16    2021-07-20
# 21396             WA             AUS       2021-07-16           NaT
# 21397             WA             AUS       2021-07-16    2021-07-20
# 21398             WA             AUS       2021-07-16    2021-07-20
# 21399             WA             AUS       2021-07-16    2021-07-20
# 30323             WA             AUS       2021-05-11    2021-05-13
# 30324             WA             AUS       2021-05-11    2021-05-13
# 30325             WA             AUS       2021-05-11    2021-05-13
# 30326             WA             AUS       2021-05-11    2021-05-13
# 30327             WA             AUS       2021-05-11    2021-05-13
# 30328             WA             AUS       2021-05-11    2021-05-13
# 30329             WA             AUS       2021-05-11    2021-05-13
# 30330             WA             AUS       2021-05-11    2021-05-13
# 30331             WA             AUS       2021-05-11    2021-05-13
# 30332             WA             AUS       2021-05-11    2021-05-13
# 30333             WA             AUS       2021-05-11    2021-05-13
# 30334             WA             AUS       2021-05-11    2021-05-13
# 30335             WA             AUS       2021-05-11    2021-05-13
# 30336             WA             AUS       2021-05-11    2021-05-13
#
#                        Item ID Drop Ship Location ID     Product Line  \
# 20800            sublined item         N         B01          service
# 21388            ABR INSURANCE         N         B01        INSURANCE
# 21389  Handling and-or cod fee         N         B01          service
# 21390                  854-214         N         B01          Swivels
# 21391        GTT-BT-Phantom-4S         N         B01              GTT
# 21392             bunsenh-5600         N         B01     Bunsen Burne
# 21393            ggt-Rock-ItFP         N         B01      FOOT PEDALS
# 21394                  cshear8         N         B01     CUTTING TOOL
# 21395                   ggt-ct         N         B01            CLAWS
# 21396          BS-BS-M-Phantom         Y         B01     Torch Marver
# 21397                  854-610         N         B01     Hoses & Acce
# 21398                 Infini-V         N         B01     BENCHROLLERS
# 21399               No Item ID         N         B01  No Product Line
# 30323            ABR INSURANCE         N         B01        INSURANCE
# 30324  Handling and-or cod fee         N         B01          service
# 30325                  850-518         N         B01          REAMERS
# 30326                  854-336         N         B01       HAND TOOLS
# 30327            ggt-cricket-L         N         B01         GRAPHITE
# 30328                 SE-DD315         N         B01     TEXTURE TOOL
# 30329              547TWEEZERS         N         B01       HAND TOOLS
# 30330                    525SF         N         B01       HAND TOOLS
# 30331                 SH-AG-A2         N         B01     CUTTING TOOL
# 30332                  854-419         N         B01         TWEEZERS
# 30333            GTT-BT-Bobcat         N         B01              GTT
# 30334             bunsenh-5805         N         B01     Bunsen Burne
# 30335                    14205         N         B01     little torch
# 30336               No Item ID         N         B01  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 20800           -1.0        ea           145.00            0.0        Percent
# 21388            1.0        EA            25.30            0.0         Amount
# 21389            1.0        EA            49.25            0.0         Amount
# 21390            1.0      Each            50.00            0.0         Amount
# 21391            1.0      EACH          1200.00            0.0         Amount
# 21392            1.0      Each            68.00            0.0         Amount
# 21393            1.0        EA           440.00            0.0         Amount
# 21394            1.0      EACH            45.00            0.0         Amount
# 21395            1.0        EA            65.00            0.0         Amount
# 21396            0.0        EA           145.00            0.0         Amount
# 21397            1.0        EA             3.00            0.0         Amount
# 21398            1.0      Each           100.00            0.0         Amount
# 21399            1.0  No Units           430.00            0.0         Amount
# 30323            1.0        EA             6.90            0.0         Amount
# 30324            1.0        EA             7.29            0.0         Amount
# 30325            1.0        EA             9.95            0.0         Amount
# 30326            1.0        EA           125.00            0.0         Amount
# 30327            1.0        EA            50.00            0.0         Amount
# 30328            1.0        EA             9.95            0.0         Amount
# 30329            1.0        EA            19.95            0.0         Amount
# 30330            1.0        EA             9.95            0.0         Amount
# 30331            2.0        EA             5.95            0.0         Amount
# 30332            2.0      EACH            14.95            0.0         Amount
# 30333            1.0      EACH           195.00            0.0         Amount
# 30334            1.0      Each            17.00            0.0         Amount
# 30335            1.0        ea            75.00            0.0         Amount
# 30336            1.0  No Units           240.15            0.0         Amount
#
#                    Ship Via   Amount
# 20800               Unknown  -145.00
# 21388  Request FREIGHT or I    25.30
# 21389  Request FREIGHT or I    49.25
# 21390  Request FREIGHT or I    50.00
# 21391  Request FREIGHT or I  1200.00
# 21392  Request FREIGHT or I    68.00
# 21393  Request FREIGHT or I   440.00
# 21394  Request FREIGHT or I    45.00
# 21395  Request FREIGHT or I    65.00
# 21396  Request FREIGHT or I     0.00
# 21397  Request FREIGHT or I     3.00
# 21398  Request FREIGHT or I   100.00
# 21399  Request FREIGHT or I   430.00
# 30323               Unknown     6.90
# 30324               Unknown     7.29
# 30325               Unknown     9.95
# 30326               Unknown   125.00
# 30327               Unknown    50.00
# 30328               Unknown     9.95
# 30329               Unknown    19.95
# 30330               Unknown     9.95
# 30331               Unknown    11.90
# 30332               Unknown    29.90
# 30333               Unknown   195.00
# 30334               Unknown    17.00
# 30335               Unknown    75.00
# 30336               Unknown   240.15

# %% [markdown]
# **Adding regions for Bloomington, Evansville, and Esperance**

# %%
data.loc[((data['Ship To Region'].isna()) & (data['Ship To City'] == 'Bloomington')), 'Ship To Region'] = 'IN'

data.loc[((data['Ship To Region'].isna()) & (data['Ship To City'] == 'Evansville')), 'Ship To Region'] = 'IN'

data.loc[((data['Ship To Region'].isna()) & (data['Ship To Country'] == 'USA') & (data['Ship To City'] == 'esperance')), 'Ship To Region'] = 'WA'

# %%
data[data['Transaction ID'] == '00179220']

#great, this worked
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 20800    Line Item       00179220      Credit Memo     bea0047    esperance
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 20800             WA             USA       2021-07-21    2021-07-21
#
#              Item ID Drop Ship Location ID Product Line  Qty Ship Sell Units  \
# 20800  sublined item         N         B01      service           -1.0    ea
#
#        Unit Price Sell  Price Adj Pct Price Adj Type Ship Via  Amount
# 20800            145.0            0.0        Percent  Unknown  -145.0

# %%
#looking through orders that have USA as shipping country but NaN Region.
data[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna())]
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 17249    Line Item       00179698          Invoice     suz0056          NaN
# 17250    Sales Tax       00179698          Invoice     suz0056          NaN
# 18155    Line Item       00179569          Invoice     dav0534          NaN
# 18156    Line Item       00179569          Invoice     dav0534          NaN
# 18157    Line Item       00179569          Invoice     dav0534          NaN
# ...            ...            ...              ...         ...          ...
# 45169    Line Item       00175502          Invoice     rus0049          NaN
# 45170    Line Item       00175502          Invoice     rus0049          NaN
# 45171    Line Item       00175502          Invoice     rus0049          NaN
# 45172    Line Item       00175502          Invoice     rus0049          NaN
# 45173    Sales Tax       00175502          Invoice     rus0049          NaN
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 17249            NaN             USA       2021-08-19    2021-08-19
# 17250            NaN             USA       2021-08-19    2021-08-19
# 18155            NaN             USA       2021-08-12    2021-08-12
# 18156            NaN             USA       2021-08-12    2021-08-12
# 18157            NaN             USA       2021-08-12    2021-08-12
# ...              ...             ...              ...           ...
# 45169            NaN             USA       2021-02-12    2021-02-12
# 45170            NaN             USA       2021-02-12    2021-02-12
# 45171            NaN             USA       2021-02-12    2021-02-12
# 45172            NaN             USA       2021-02-12           NaT
# 45173            NaN             USA       2021-02-12    2021-02-12
#
#                    Item ID Drop Ship Location ID     Product Line  \
# 17249       Glassseparator         N         B01     Kiln Accesso
# 17250           No Item ID         N         B01  No Product Line
# 18155              GLOa1lb         N         B01      GLOW POWDER
# 18156          DH20HOLETIP         N         B01     National Com
# 18157  BB-BoroBatch-Shorts         N         B01       Boro Batch
# ...                    ...       ...         ...              ...
# 45169           glasscuttr         N         B01     CUTTING TOOL
# 45170            246190250         N         B01     Simax Tubing
# 45171            246190320         N         B01     Simax Tubing
# 45172              854-399         N         B01     CUTTING TOOL
# 45173           No Item ID         N         B01  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 17249            1.0        EA            7.784            0.0        Percent
# 17250            1.0  No Units            0.540            0.0         Amount
# 18155            1.0       5GR            5.000            0.0        Percent
# 18156            1.0      each           50.000            0.0        Percent
# 18157            1.0        LB           15.000            0.0        Percent
# ...              ...       ...              ...            ...            ...
# 45169            1.0      EACH           15.950            0.0        Percent
# 45170            1.0        PC            6.343            0.0        Percent
# 45171            1.0        PC            7.766            0.0        Percent
# 45172            0.0        EA           54.950            0.0        Percent
# 45173            1.0  No Units            2.100            0.0         Amount
#
#                Ship Via  Amount
# 17249           Unknown    7.78
# 17250           Unknown    0.54
# 18155  Pick Up Thursday    5.00
# 18156  Pick Up Thursday   50.00
# 18157  Pick Up Thursday   15.00
# ...                 ...     ...
# 45169           Pick Up   15.95
# 45170           Pick Up    6.34
# 45171           Pick Up    7.77
# 45172           Pick Up    0.00
# 45173           Pick Up    2.10
#
# [74 rows x 20 columns]

# %%
#so any order with sales tax here is a pick up order. All the orders above have Sales Tax, so the City and Region can be set to Bloomington, IN
data.loc[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna()), 'Ship To City'] = 'Bloomington'

data.loc[(data['Ship To Country'] == 'USA') & (data['Ship To Region'].isna()), 'Ship To Region'] = 'Indiana'

# %%
#this is confirming that the remaining NaN regions in the data is in foreign countries and therefore do not need this information
data[data['Ship To Region'].isna()]['Ship To Country'].value_counts()
# Out:
# JPN       307
# DEU       231
# FRA       137
# GBR        80
# AUS        51
# CHL        43
# ITA        41
# MEX        32
# FRANCE     27
# THA        25
# ARG        14
# NZL        12
# BEL        11
# IRL        10
# JAPAN       7
# CHN         4
# IND         3
# CHE         2
# Name: Ship To Country, dtype: int64

# %%
#looing at the remaining NaN cities
data[data['Ship To City'].isna()]
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 0          Payment       00207311          Payment     hun0016          NaN
# 1          Payment       00207321          Payment     lid0001          NaN
# 2          Payment       00207309          Payment     rob0274          NaN
# 3          Payment       00207315          Payment     jac0117          NaN
# 4          Payment       00207318          Payment     max0010          NaN
# ...            ...            ...              ...         ...          ...
# 52792      Payment       00191080          Payment     ada0153          NaN
# 52793      Payment       00191078          Payment     die0005          NaN
# 52959      Payment       00191070          Payment     ran0051          NaN
# 52960      Payment       00191077          Payment     nic0216          NaN
# 52961      Payment       00191102          Payment     cha0637          NaN
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 0                NaN             NaN       2021-12-30           NaT
# 1                NaN             NaN       2021-12-30           NaT
# 2                NaN             NaN       2021-12-30           NaT
# 3                NaN             NaN       2021-12-30           NaT
# 4                NaN             NaN       2021-12-30           NaT
# ...              ...             ...              ...           ...
# 52792            NaN             NaN       2021-01-02           NaT
# 52793            NaN             NaN       2021-01-02           NaT
# 52959            NaN             NaN       2021-01-02           NaT
# 52960            NaN             NaN       2021-01-01           NaT
# 52961            NaN             NaN       2021-01-01           NaT
#
#           Item ID Drop Ship Location ID     Product Line  Qty Ship Sell  \
# 0      No Item ID         N         NaN  No Product Line            0.0
# 1      No Item ID         N         NaN  No Product Line            0.0
# 2      No Item ID         N         NaN  No Product Line            0.0
# 3      No Item ID         N         NaN  No Product Line            0.0
# 4      No Item ID         N         NaN  No Product Line            0.0
# ...           ...       ...         ...              ...            ...
# 52792  No Item ID         N         NaN  No Product Line            0.0
# 52793  No Item ID         N         NaN  No Product Line            0.0
# 52959  No Item ID         N         NaN  No Product Line            0.0
# 52960  No Item ID         N         NaN  No Product Line            0.0
# 52961  No Item ID         N         NaN  No Product Line            0.0
#
#           Units  Unit Price Sell  Price Adj Pct Price Adj Type Ship Via  \
# 0      No Units              0.0            0.0         Amount  Unknown
# 1      No Units              0.0            0.0         Amount  Unknown
# 2      No Units              0.0            0.0         Amount  Unknown
# 3      No Units              0.0            0.0         Amount  Unknown
# 4      No Units              0.0            0.0         Amount  Unknown
# ...         ...              ...            ...            ...      ...
# 52792  No Units              0.0            0.0         Amount  Unknown
# 52793  No Units              0.0            0.0         Amount  Unknown
# 52959  No Units              0.0            0.0         Amount  Unknown
# 52960  No Units              0.0            0.0         Amount  Unknown
# 52961  No Units              0.0            0.0         Amount  Unknown
#
#         Amount
# 0      -380.94
# 1      -325.40
# 2      -703.84
# 3       -89.53
# 4       -34.78
# ...        ...
# 52792  -265.24
# 52793  -798.49
# 52959 -1592.50
# 52960 -1076.35
# 52961   -52.72
#
# [6033 rows x 20 columns]

# %%
# for Transaction ID 0018138, looked in Traverse and the city is Atlanta, will change this
data.loc[(data['Transaction ID'] == '00181389'), 'Ship To City'] = 'Atlanta'

# %% [markdown]
# **removing History type of Payment**

# %%
data = data.loc[(data['History Type'] != 'Payment')]

# %% [markdown]
# ## **Correcting Foreign Countries**

# %%
data['Ship To Country'].value_counts()
# Out:
# USA       44351
# CAN        1178
# JPN         348
# DEU         244
# JAPAN       153
# FRA         137
# AUS          96
# GBR          91
# MEX          70
# CHL          43
# ITA          41
# FRANCE       27
# THA          25
# BRB          21
# CHINA        18
# ARG          14
# NZL          12
# BEL          11
# IRL          10
# Canada        9
# CHN           7
# CHE           6
# IND           3
# ISR           3
# Name: Ship To Country, dtype: int64

# %%
# changing FRA to FRANCE
data.loc[(data['Ship To Country'] == 'FRA'), 'Ship To Country'] = 'FRANCE'

#chaning JPN to JAPAN
data.loc[(data['Ship To Country'] == 'JPN'), 'Ship To Country'] = 'JAPAN'

#changing CHN to CHINA
data.loc[(data['Ship To Country'] == 'CHN'), 'Ship To Country'] = 'CHINA'

#changing CHE to SWITZERLAMD
data.loc[(data['Ship To Country'] == 'CHE'), 'Ship To Country'] = 'SWITZERLAND'
# Out:
# C:\Users\cs.ABR\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# ## **Correcting States in the USA**

# %%
data.loc[(data['Ship To Country'] == 'USA'), 'Ship To Region'].value_counts()
# Out:
# CA    4650
# IN    2625
# FL    2560
# TX    2497
# AZ    2491
#       ...
# sd       1
# Ia       1
# ks       1
# wv       1
# nh       1
# Name: Ship To Region, Length: 101, dtype: int64

# %%
# Arizona
data.loc[(data['Ship To Region'] == 'az'), 'Ship To Region'] = 'AZ'
data.loc[(data['Ship To Region'] == 'AZPHOENIX'), 'Ship To Region'] = 'AZ'

# California
data.loc[(data['Ship To Region'] == 'ca'), 'Ship To Region'] = 'CA'

# Colorado
data.loc[(data['Ship To Region'] == 'Co'), 'Ship To Region'] = 'CO'
data.loc[(data['Ship To Region'] == 'co'), 'Ship To Region'] = 'CO'

# Connecticut
data.loc[(data['Ship To Region'] == 'ct'), 'Ship To Region'] = 'CT'

# Delaware
data.loc[(data['Ship To Region'] == 'DL'), 'Ship To Region'] = 'DE'

# Florida
data.loc[(data['Ship To Region'] == 'fl'), 'Ship To Region'] = 'FL'

# Georgia
data.loc[(data['Ship To Region'] == 'ga'), 'Ship To Region'] = 'GA'

# Hawaii
data.loc[(data['Ship To Region'] == 'Hi'), 'Ship To Region'] = 'HI'

# Iowa
data.loc[(data['Ship To Region'] == 'Ia'), 'Ship To Region'] = 'IA'
data.loc[(data['Ship To Region'] == 'ia'), 'Ship To Region'] = 'IA'


# Idaho

data.loc[(data['Ship To Region'] == 'id'), 'Ship To Region'] = 'ID'

# Illinois
data.loc[(data['Ship To Region'] == 'il'), 'Ship To Region'] = 'IL'
data.loc[(data['Ship To Region'] == 'IL'), 'Ship To Region'] = 'FL'

# Indiana
data.loc[(data['Ship To Region'] == 'indiana'), 'Ship To Region'] = 'IN'
data.loc[(data['Ship To Region'] == 'Indiana'), 'Ship To Region'] = 'IN'
data.loc[(data['Ship To Region'] == 'in'), 'Ship To Region'] = 'IN'
data.loc[(data['Ship To Region'] == 'In'), 'Ship To Region'] = 'IN'
data.loc[(data['Ship To Region'] == 'johnson'), 'Ship To Region'] = 'IN'

# Kansas
data.loc[(data['Ship To Region'] == 'ks'), 'Ship To Region'] = 'KS'

# Louisiana
data.loc[(data['Ship To Region'] == 'la'), 'Ship To Region'] = 'LA'

# Massachusetts
data.loc[(data['Ship To Region'] == 'ma'), 'Ship To Region'] = 'MA'

# Maine
data.loc[(data['Ship To Region'] == 'Me'), 'Ship To Region'] = 'ME'
data.loc[(data['Ship To Region'] == 'me'), 'Ship To Region'] = 'ME'

# Michigan
data.loc[(data['Ship To Region'] == 'mi'), 'Ship To Region'] = 'MI'

# Minnesota
data.loc[(data['Ship To Region'] == 'mn'), 'Ship To Region'] = 'MN'

# Missouri
data.loc[(data['Ship To Region'] == 'mo'), 'Ship To Region'] = 'MO'

# Mississippi
data.loc[(data['Ship To Region'] == 'ms'), 'Ship To Region'] = 'MS'

# North Carolina
data.loc[(data['Ship To Region'] == 'nc'), 'Ship To Region'] = 'NC'

# New Hampshire
data.loc[(data['Ship To Region'] == 'nh'), 'Ship To Region'] = 'NH'

# New Jersey
data.loc[(data['Ship To Region'] == 'nj'), 'Ship To Region'] = 'NJ'

# New Mexico
data.loc[(data['Ship To Region'] == 'nm'), 'Ship To Region'] = 'NM'

# Nevada
data.loc[(data['Ship To Region'] == 'nv'), 'Ship To Region'] = 'NV'

# New York
data.loc[(data['Ship To Region'] == 'ny'), 'Ship To Region'] = 'NY'

# Ohio
data.loc[(data['Ship To Region'] == 'oh'), 'Ship To Region'] = 'OH'

# Oklahoma
data.loc[(data['Ship To Region'] == 'ok'), 'Ship To Region'] = 'OK'

# Oregon
data.loc[(data['Ship To Region'] == 'or'), 'Ship To Region'] = 'OR'

# Pennsylvania 
data.loc[(data['Ship To Region'] == 'pa'), 'Ship To Region'] = 'PA'

# Rhode Island
data.loc[(data['Ship To Region'] == 'ri'), 'Ship To Region'] = 'RI'

# South Dakota
data.loc[(data['Ship To Region'] == 'sd'), 'Ship To Region'] = 'SD'

# Tennessee 
data.loc[(data['Ship To Region'] == 'tn'), 'Ship To Region'] = 'TN'

# Texas
data.loc[(data['Ship To Region'] == 'tx'), 'Ship To Region'] = 'TX'

# Utah
data.loc[(data['Ship To Region'] == 'ut'), 'Ship To Region'] = 'UT'

# Virginia
data.loc[(data['Ship To Region'] == 'va'), 'Ship To Region'] = 'VA'
data.loc[(data['Ship To Region'] == 'Virginia'), 'Ship To Region'] = 'VA'

# Washington
data.loc[(data['Ship To Region'] == 'wa'), 'Ship To Region'] = 'WA'

# Wisconsin
data.loc[(data['Ship To Region'] == 'wi'), 'Ship To Region'] = 'WI'

# West Virginia
data.loc[(data['Ship To Region'] == 'wv'), 'Ship To Region'] = 'WV'

# Wyoming
data.loc[(data['Ship To Region'] == 'wy'), 'Ship To Region'] = 'WY'

# %% [markdown]
# **There are Ship To Regions with the value of 'A',I will have to look through these and correct them**

# %%
data[data['Ship To Region'] == 'A'].info()  #there are 71 entries with 'A'
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 71 entries, 12090 to 48441
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   History Type      71 non-null     object
#  1   Transaction ID    71 non-null     object
#  2   Transaction Type  71 non-null     object
#  3   Customer ID       71 non-null     object
#  4   Ship To City      71 non-null     object
#  5   Ship To Region    71 non-null     object
#  6   Ship To Country   71 non-null     object
#  7   Transaction Date  71 non-null     datetime64[ns]
#  8   Act Ship Date     70 non-null     datetime64[ns]
#  9   Item ID           71 non-null     object
#  10  Drop Ship         71 non-null     object
#  11  Location ID       71 non-null     object
#  12  Product Line      71 non-null     object
#  13  Qty Ship Sell     71 non-null     float64
#  14  Units             71 non-null     object
#  15  Unit Price Sell   71 non-null     float64
#  16  Price Adj Pct     71 non-null     float64
#  17  Price Adj Type    71 non-null     object
#  18  Ship Via          71 non-null     object
#  19  Amount            71 non-null     float64
# dtypes: datetime64[ns](2), float64(4), object(14)
# memory usage: 11.6+ KB

# %%
# looking through these orders to determine the region
data[data['Ship To Region'] == 'A']
# Out:
#       History Type Transaction ID Transaction Type Customer ID Ship To City  \
# 12090    Line Item       00180480          Invoice     Eva0223       Dallas
# 12091    Line Item       00180480          Invoice     Eva0223       Dallas
# 12092    Line Item       00180480          Invoice     Eva0223       Dallas
# 12093    Line Item       00180480          Invoice     Eva0223       Dallas
# 12094      Freight       00180480          Invoice     Eva0223       Dallas
# ...            ...            ...              ...         ...          ...
# 48437    Line Item       00175045          Invoice     pad0004   Germantown
# 48438    Line Item       00175045          Invoice     pad0004   Germantown
# 48439    Line Item       00175045          Invoice     pad0004   Germantown
# 48440    Line Item       00175045          Invoice     pad0004   Germantown
# 48441      Freight       00175045          Invoice     pad0004   Germantown
#
#       Ship To Region Ship To Country Transaction Date Act Ship Date  \
# 12090              A             USA       2021-09-29    2021-10-01
# 12091              A             USA       2021-09-29    2021-10-01
# 12092              A             USA       2021-09-29           NaT
# 12093              A             USA       2021-09-29    2021-10-01
# 12094              A             USA       2021-09-29    2021-10-01
# ...              ...             ...              ...           ...
# 48437              A             USA       2021-01-25    2021-01-27
# 48438              A             USA       2021-01-25    2021-01-27
# 48439              A             USA       2021-01-25    2021-01-27
# 48440              A             USA       2021-01-25    2021-01-27
# 48441              A             USA       2021-01-25    2021-01-27
#
#                        Item ID Drop Ship Location ID     Product Line  \
# 12090            ABR INSURANCE         N         B01        INSURANCE
# 12091  Handling and-or cod fee         N         B01          service
# 12092          TAG-033-T-1-001         N         B01     TAG COLORED
# 12093                   onst78         N         B01     Northstar Tu
# 12094               No Item ID         N         B01  No Product Line
# ...                        ...       ...         ...              ...
# 48437            ABR INSURANCE         N         B01        INSURANCE
# 48438  Handling and-or cod fee         N         B01          service
# 48439                  nswt003         N         B01     Northstar Wo
# 48440                    NST54         N         B01     Northstar Tu
# 48441               No Item ID         N         B01  No Product Line
#
#        Qty Ship Sell     Units  Unit Price Sell  Price Adj Pct Price Adj Type  \
# 12090            1.0        EA             2.30            0.0         Amount
# 12091            1.0        EA             1.70            0.0         Amount
# 12092            0.0        LB            67.50            0.0         Amount
# 12093            0.9        LB            42.00            0.0         Amount
# 12094            1.0  No Units            19.19            0.0         Amount
# ...              ...       ...              ...            ...            ...
# 48437            1.0        EA             1.40            0.0         Amount
# 48438            1.0        EA             2.15            0.0         Amount
# 48439            1.0        LB            80.10            0.0         Amount
# 48440            1.0        LB            58.50            0.0         Amount
# 48441            1.0  No Units            25.11            0.0         Amount
#
#       Ship Via  Amount
# 12090      GND    2.30
# 12091      GND    1.70
# 12092      GND    0.00
# 12093      GND   37.80
# 12094      GND   19.19
# ...        ...     ...
# 48437      GND    1.40
# 48438      GND    2.15
# 48439      GND   80.10
# 48440      GND   58.50
# 48441      GND   25.11
#
# [71 rows x 20 columns]

# %% [markdown]
# These orders need to have the Ship To Region of 'A' changed
#
# Transaction ID    Ship To Region
# 00180480          TX
# 00179003          TX
# 00178268          CA
# 00178138          CA
# 00177616          OH
# 00177125          MI
# 00176522          CO
# 00176501          CA
# 00176392          NY
# 00175839          NY
# 00175093          CA
# 00175045          NY

# %%
#changing the Ship To Regions 
data.loc[(data['Transaction ID'] == '00180480'), 'Ship To Region'] = 'TX'

data.loc[(data['Transaction ID'] == '00179003'), 'Ship To Region'] = 'TX'

data.loc[(data['Transaction ID'] == '00178268'), 'Ship To Region'] = 'CA'

data.loc[(data['Transaction ID'] == '00178138'), 'Ship To Region'] = 'CA'

data.loc[(data['Transaction ID'] == '00177616'), 'Ship To Region'] = 'OH'

data.loc[(data['Transaction ID'] == '00177125'), 'Ship To Region'] = 'MI'

data.loc[(data['Transaction ID'] == '00176522'), 'Ship To Region'] = 'CO'

data.loc[(data['Transaction ID'] == '00176501'), 'Ship To Region'] = 'CA'

data.loc[(data['Transaction ID'] == '00176392'), 'Ship To Region'] = 'NY'

data.loc[(data['Transaction ID'] == '00175839'), 'Ship To Region'] = 'NY'

data.loc[(data['Transaction ID'] == '00175093'), 'Ship To Region'] = 'CA'

data.loc[(data['Transaction ID'] == '00175045'), 'Ship To Region'] = 'NY'
# Out:
# C:\Users\cs.ABR\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# Great, There is no longer any data that has 'A' for the Ship To Region
data[data['Ship To Region'] == 'A']
# Out:
# Empty DataFrame
# Columns: [History Type, Transaction ID, Transaction Type, Customer ID, Ship To City, Ship To Region, Ship To Country, Transaction Date, Act Ship Date, Item ID, Drop Ship, Location ID, Product Line, Qty Ship Sell, Units, Unit Price Sell, Price Adj Pct, Price Adj Type, Ship Via, Amount]
# Index: []

# %% [markdown]
# # There are Freight History Types that need to have their Item ID switched over to 'FREIGHT' as this will make more sense with my visualizations

# %%
# viewing History Types with No Item ID
data.loc[(data['Item ID'] == 'No Item ID'), 'History Type'].value_counts()
# Out:
# Freight      4977
# Sales Tax     582
# Misc            1
# Name: History Type, dtype: int64

# %%
# changing Item ID in rows with History Type of 'Freight' to 'Freight'
data.loc[((data['Item ID'] == 'No Item ID') & (data['History Type'] == 'Freight')), 'Item ID'] = 'Freight'

# changing Item ID in rows with History Type of 'Sales Tax' to 'Sales Tax'
data.loc[((data['Item ID'] == 'No Item ID') & (data['History Type'] == 'Sales Tax')), 'Item ID'] = 'Sales Tax'
# Out:
# C:\Users\cs.ABR\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %% [markdown]
# # Adding Customer Names

# %% [markdown]
# **Generated a full list of customer information in Traverse. The file is called AR Customer View.Xls**

# %%
#loading in file
wb = xlrd.open_workbook('AR Customer View.Xls', logfile = open(devnull, 'w'))
customer_info = pd.read_excel(wb)

# %%
#keeping info of customer id and name in the dataframe customer_info
customer_info = customer_info[['Customer ID', 'Name']]
customer_info.head()
# Out:
#   Customer ID           Name
# 0           -            NaN
# 1     cha0001           Bret
# 2    cha0001            NaN
# 3     cor0089   Cory McGrady
# 4     der0012  Derick Miller

# %%
#checking for duplicates
customer_info['Customer ID'].duplicated().sum()
# Out:
# 0

# %%
#looking at the count of customer id in the data to see if this remains the same after the join
data['Customer ID'].count()
# Out:
# 46918

# %%
#merging main dataset and customer info
data = data.merge(customer_info, on = 'Customer ID', how = 'left')

# %%
# Customer ID did remain the same, this is good, the join worked as expected
data['Customer ID'].count()
# Out:
# 46918

# %% [markdown]
# ## Great! I believe this data is ready for Visualization. will write to a file

# %%
data.to_csv('ABR Imagery 2021 Orders.csv', index = False)

# %% [markdown]
# **double checking the calculations in Tableau with Python, since I trust My python much much more**
